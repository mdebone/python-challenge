# %%
# Dependencies
import os
import json
from pathlib import Path

# load JSON
filepath = os.path.join("Resources", "youtube_response.json")
with open(filepath) as jsonfile:
    video_json = json.load(jsonfile)

# %%
print(json.dumps(video_json, indent=4))
# Out:
# {
#     "apiVersion": "2.0",
#     "data": {
#         "updated": "2010-01-07T19:58:42.949Z",
#         "totalItems": 800,
#         "startIndex": 1,
#         "itemsPerPage": 1,
#         "items": [
#             {
#                 "id": "hYB0mn5zh2c",
#                 "uploaded": "2007-06-05T22:07:03.000Z",
#                 "updated": "2010-01-07T13:26:50.000Z",
#                 "uploader": "GoogleDeveloperDay",
#                 "category": "News",
#                 "title": "Google Developers Day US - Maps API Introduction",
#                 "description": "Google Maps API Introduction ...",
#                 "tags": [
#                     "GDD07",
#                     "GDD07US",
#                     "Maps"
#                 ],
#                 "thumbnail": {
#                     "default": "http://i.ytimg.com/vi/hYB0mn5zh2c/default.jpg",
#                     "hqDefault": "http://i.ytimg.com/vi/hYB0mn5zh2c/hqdefault.jpg"
#                 },
#                 "player": {
#                     "default": "http://www.youtube.com/watch?vu003dhYB0mn5zh2c"
#                 },
#                 "content": {
#                     "1": "rtsp://v5.cache3.c.youtube.com/CiILENy.../0/0/0/video.3gp",
#                     "5": "http://www.youtube.com/v/hYB0mn5zh2c?f...",
#                     "6": "rtsp://v1.cache1.c.youtube.com/CiILENy.../0/0/0/video.3gp"
#                 },
#                 "duration": 2840,
#                 "aspectRatio": "widescreen",
#                 "rating": 4.63,
#                 "ratingCount": 68,
#                 "viewCount": 220101,
#                 "favoriteCount": 201,
#                 "commentCount": 22,
#                 "status": {
#                     "value": "restricted",
#                     "reason": "limitedSyndication"
#                 },
#                 "accessControl": {
#                     "syndicate": "allowed",
#                     "commentVote": "allowed",
#                     "rate": "allowed",
#                     "list": "allowed",
#                     "comment": "allowed",
#                     "embed": "allowed",
#                     "videoRespond": "moderated"
#                 }
#             }
#         ]
#     }
# }

# %%
print(video_json["data"]["items"][0]["thumbnail"]["hqDefault"])
# Out:
# http://i.ytimg.com/vi/hYB0mn5zh2c/hqdefault.jpg

# %%
for x in video_json["data"]["items"]:
    print(x["thumbnail"]["hqDefault"])
# Out:
# http://i.ytimg.com/vi/hYB0mn5zh2c/hqdefault.jpg

# %%
title = video_json["data"]["items"][0]["title"]

# %%
#Isolate "data items" for easy reading
data = video_json["data"]
data_items = video_json["data"]["items"]
for x in data_items:
        print(f"Title: {x['title']}")
        print(f"Rating: {x['rating']}")
        print("Thumbnail: ", {x['thumbnail']['default']})
        print(f"view count: {x['viewCount']}")
# Out:
# Title: Google Developers Day US - Maps API Introduction
# Rating: 4.63
# Thumbnail:  {'http://i.ytimg.com/vi/hYB0mn5zh2c/default.jpg'}
# view count: 220101

# %%
# Retrieve the video's title
title = data_items[0]["title"]
print("Title: ", title)
# Out:
# Title:  Google Developers Day US - Maps API Introduction

# %%
# Retrieve the video's rating
rating = data_items[0]["rating"]
print("Rating:", rating)
# Out:
# Rating: 4.63

# %%
# Retrieve the link to the video's default thumbnail
default_thumbnail = data_items[0]["thumbnail"]["default"]
print("Thumbnail:", default_thumbnail)
# Out:
# Thumbnail: http://i.ytimg.com/vi/hYB0mn5zh2c/default.jpg

# %%
# Retrieve the number of views
views = data_items[0]["viewCount"]
print("Viewcount:", views)
# Out:
# Viewcount: 220101

# %%
from IPython.core.display import display, HTML
html = f'''
<a target="blank" href="{x['content']}">{x['title']}</a> ({x['viewCount']:,.0f})<br>
Ratings: {x['rating']}
<img src='{x['thumbnail']['default']}'>
'''
display(HTML(html))
# Out:
# <a target="blank" href="{'1': 'rtsp://v5.cache3.c.youtube.com/CiILENy.../0/0/0/video.3gp', '5': 'http://www.youtube.com/v/hYB0mn5zh2c?f...', '6': 'rtsp://v1.cache1.c.youtube.com/CiILENy.../0/0/0/video.3gp'}">Google Developers Day US - Maps API Introduction</a> (220,101)<br>
# Ratings: 4.63
# <img src='http://i.ytimg.com/vi/hYB0mn5zh2c/default.jpg'>

# %%
#2.2
# Dependencies
import json
import requests
from pprint import pprint

# %%
# Specify the URL
url = "https://2u-data-curriculum-team.s3.amazonaws.com/dataviz-classroom/v1.1/06-Python-APIs/request_review.json"

# Make request and store the response
response = requests.get(url)

# Verify the status code
response.status_code
# Out:
# 200

# %%
#JSONify response
response_json = response.json()
pprint(response_json)
# Out:
# [{'common_name': 'Tiger cat',
#   'id': 1,
#   'info': 'Curabitur at ipsum ac tellus semper interdum. Mauris ullamcorper '
#           'purus sit amet nulla. Quisque arcu libero, rutrum ac, lobortis vel, '
#           'dapibus at, diam.',
#   'location': 'Russia',
#   'scientific_name': 'Dasyurus maculatus'},
#  {'common_name': 'Crab-eating fox',
#   'id': 2,
#   'info': 'Vestibulum ac est lacinia nisi venenatis tristique. Fusce congue, '
#           'diam id ornare imperdiet, sapien urna pretium nisl, ut volutpat '
#           'sapien arcu sed augue. Aliquam erat volutpat.\n'
#           '\n'
#           'In congue. Etiam justo. Etiam pretium iaculis justo.',
#   'location': 'Sweden',
#   'scientific_name': 'Dusicyon thous'},
#  {'common_name': 'Pelican, brown',
#   'id': 3,
#   'info': 'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.\n'
#           '\n'
#           'Proin interdum mauris non ligula pellentesque ultrices. Phasellus '
#           'id sapien in sapien iaculis congue. Vivamus metus arcu, adipiscing '
#           'molestie, hendrerit at, vulputate vitae, nisl.',
#   'location': 'China',
#   'scientific_name': 'Pelecanus occidentalis'},
#  {'common_name': 'Mongoose, banded',
#   'id': 4,
#   'info': 'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.',
#   'location': 'Armenia',
#   'scientific_name': 'Mungos mungo'},
#  {'common_name': 'Chital',
#   'id': 5,
#   'info': 'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'Portugal',
#   'scientific_name': 'Axis axis'},
#  {'common_name': 'Skunk, western spotted',
#   'id': 6,
#   'info': 'Quisque id justo sit amet sapien dignissim vestibulum. Vestibulum '
#           'ante ipsum primis in faucibus orci luctus et ultrices posuere '
#           'cubilia Curae; Nulla dapibus dolor vel est. Donec odio justo, '
#           'sollicitudin ut, suscipit a, feugiat et, eros.',
#   'location': 'Myanmar',
#   'scientific_name': 'Spilogale gracilis'},
#  {'common_name': 'Zorilla',
#   'id': 7,
#   'info': 'Fusce consequat. Nulla nisl. Nunc nisl.\n'
#           '\n'
#           'Duis bibendum, felis sed interdum venenatis, turpis enim blandit '
#           'mi, in porttitor pede justo eu massa. Donec dapibus. Duis at velit '
#           'eu est congue elementum.',
#   'location': 'China',
#   'scientific_name': 'Ictonyx striatus'},
#  {'common_name': 'Western pygmy possum',
#   'id': 8,
#   'info': 'In quis justo. Maecenas rhoncus aliquam lacus. Morbi quis tortor id '
#           'nulla ultrices aliquet.\n'
#           '\n'
#           'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.',
#   'location': 'Croatia',
#   'scientific_name': 'Cercatetus concinnus'},
#  {'common_name': 'Wambenger, red-tailed',
#   'id': 9,
#   'info': 'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.\n'
#           '\n'
#           'Curabitur gravida nisi at nibh. In hac habitasse platea dictumst. '
#           'Aliquam augue quam, sollicitudin vitae, consectetuer eget, rutrum '
#           'at, lorem.',
#   'location': 'Sweden',
#   'scientific_name': 'Phascogale calura'},
#  {'common_name': 'Otter, canadian river',
#   'id': 10,
#   'info': 'Integer tincidunt ante vel ipsum. Praesent blandit lacinia erat. '
#           'Vestibulum sed magna at nunc commodo placerat.\n'
#           '\n'
#           'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.',
#   'location': 'China',
#   'scientific_name': 'Lutra canadensis'},
#  {'common_name': 'Brown antechinus',
#   'id': 11,
#   'info': 'In hac habitasse platea dictumst. Morbi vestibulum, velit id '
#           'pretium iaculis, diam erat fermentum justo, nec condimentum neque '
#           'sapien placerat ante. Nulla justo.\n'
#           '\n'
#           'Aliquam quis turpis eget elit sodales scelerisque. Mauris sit amet '
#           'eros. Suspendisse accumsan tortor quis turpis.',
#   'location': 'China',
#   'scientific_name': 'Antechinus flavipes'},
#  {'common_name': 'Tortoise, galapagos',
#   'id': 12,
#   'info': 'In hac habitasse platea dictumst. Morbi vestibulum, velit id '
#           'pretium iaculis, diam erat fermentum justo, nec condimentum neque '
#           'sapien placerat ante. Nulla justo.',
#   'location': 'China',
#   'scientific_name': 'Geochelone elephantopus'},
#  {'common_name': "Coke's hartebeest",
#   'id': 13,
#   'info': 'Curabitur in libero ut massa volutpat convallis. Morbi odio odio, '
#           'elementum eu, interdum eu, tincidunt in, leo. Maecenas pulvinar '
#           'lobortis est.',
#   'location': 'Croatia',
#   'scientific_name': 'Alcelaphus buselaphus cokii'},
#  {'common_name': 'Thrasher, curve-billed',
#   'id': 14,
#   'info': 'In hac habitasse platea dictumst. Etiam faucibus cursus urna. Ut '
#           'tellus.',
#   'location': 'France',
#   'scientific_name': 'Toxostoma curvirostre'},
#  {'common_name': 'Pine siskin',
#   'id': 15,
#   'info': 'Proin leo odio, porttitor id, consequat in, consequat ut, nulla. '
#           'Sed accumsan felis. Ut at dolor quis odio consequat varius.\n'
#           '\n'
#           'Integer ac leo. Pellentesque ultrices mattis odio. Donec vitae '
#           'nisi.',
#   'location': 'Brazil',
#   'scientific_name': 'Carduelis pinus'},
#  {'common_name': 'Owl, madagascar hawk',
#   'id': 16,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'Slovenia',
#   'scientific_name': 'Ninox superciliaris'},
#  {'common_name': 'Blue and gold macaw',
#   'id': 17,
#   'info': 'Aenean fermentum. Donec ut mauris eget massa tempor convallis. '
#           'Nulla neque libero, convallis eget, eleifend luctus, ultricies eu, '
#           'nibh.',
#   'location': 'Philippines',
#   'scientific_name': 'Ara ararauna'},
#  {'common_name': 'Cape Barren goose',
#   'id': 18,
#   'info': 'Aliquam quis turpis eget elit sodales scelerisque. Mauris sit amet '
#           'eros. Suspendisse accumsan tortor quis turpis.',
#   'location': 'Cameroon',
#   'scientific_name': 'Cereopsis novaehollandiae'},
#  {'common_name': 'Canadian tiger swallowtail butterfly',
#   'id': 19,
#   'info': 'Nulla ut erat id mauris vulputate elementum. Nullam varius. Nulla '
#           'facilisi.\n'
#           '\n'
#           'Cras non velit nec nisi vulputate nonummy. Maecenas tincidunt lacus '
#           'at velit. Vivamus vel nulla eget eros elementum pellentesque.',
#   'location': 'China',
#   'scientific_name': 'Papilio canadensis'},
#  {'common_name': 'Agouti',
#   'id': 20,
#   'info': 'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.\n'
#           '\n'
#           'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.',
#   'location': 'China',
#   'scientific_name': 'Dasyprocta leporina'},
#  {'common_name': 'Klipspringer',
#   'id': 21,
#   'info': 'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
#           'ipsum. Integer a nibh.\n'
#           '\n'
#           'In quis justo. Maecenas rhoncus aliquam lacus. Morbi quis tortor id '
#           'nulla ultrices aliquet.',
#   'location': 'United States',
#   'scientific_name': 'Oreotragus oreotragus'},
#  {'common_name': 'Woodrat (unidentified)',
#   'id': 22,
#   'info': 'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.\n'
#           '\n'
#           'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.',
#   'location': 'Panama',
#   'scientific_name': 'Neotoma sp.'},
#  {'common_name': 'Nelson ground squirrel',
#   'id': 23,
#   'info': 'Proin interdum mauris non ligula pellentesque ultrices. Phasellus '
#           'id sapien in sapien iaculis congue. Vivamus metus arcu, adipiscing '
#           'molestie, hendrerit at, vulputate vitae, nisl.',
#   'location': 'Colombia',
#   'scientific_name': 'Ammospermophilus nelsoni'},
#  {'common_name': 'African darter',
#   'id': 24,
#   'info': 'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.\n'
#           '\n'
#           'Fusce consequat. Nulla nisl. Nunc nisl.',
#   'location': 'China',
#   'scientific_name': 'Anhinga rufa'},
#  {'common_name': 'Mississippi alligator',
#   'id': 25,
#   'info': 'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.\n'
#           '\n'
#           'Morbi non lectus. Aliquam sit amet diam in magna bibendum '
#           'imperdiet. Nullam orci pede, venenatis non, sodales sed, tincidunt '
#           'eu, felis.',
#   'location': 'Spain',
#   'scientific_name': 'Alligator mississippiensis'},
#  {'common_name': 'Plains zebra',
#   'id': 26,
#   'info': 'Quisque porta volutpat erat. Quisque erat eros, viverra eget, '
#           'congue eget, semper rutrum, nulla. Nunc purus.\n'
#           '\n'
#           'Phasellus in felis. Donec semper sapien a libero. Nam dui.',
#   'location': 'Sweden',
#   'scientific_name': 'Equus burchelli'},
#  {'common_name': 'Sea birds (unidentified)',
#   'id': 27,
#   'info': 'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.',
#   'location': 'North Korea',
#   'scientific_name': 'unavailable'},
#  {'common_name': "Squirrel, richardson's ground",
#   'id': 28,
#   'info': 'Suspendisse potenti. In eleifend quam a odio. In hac habitasse '
#           'platea dictumst.\n'
#           '\n'
#           'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.',
#   'location': 'China',
#   'scientific_name': 'Spermophilus richardsonii'},
#  {'common_name': 'Otter, small-clawed',
#   'id': 29,
#   'info': 'Sed sagittis. Nam congue, risus semper porta volutpat, quam pede '
#           'lobortis ligula, sit amet eleifend pede libero quis orci. Nullam '
#           'molestie nibh in lectus.\n'
#           '\n'
#           'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'Indonesia',
#   'scientific_name': 'Aonyx cinerea'},
#  {'common_name': 'Mongoose, javan gold-spotted',
#   'id': 30,
#   'info': 'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.',
#   'location': 'China',
#   'scientific_name': 'Herpestes javanicus'},
#  {'common_name': 'Water legaan',
#   'id': 31,
#   'info': 'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.\n'
#           '\n'
#           'Curabitur gravida nisi at nibh. In hac habitasse platea dictumst. '
#           'Aliquam augue quam, sollicitudin vitae, consectetuer eget, rutrum '
#           'at, lorem.',
#   'location': 'United States',
#   'scientific_name': 'Varanus salvator'},
#  {'common_name': 'Neotropic cormorant',
#   'id': 32,
#   'info': 'Morbi non lectus. Aliquam sit amet diam in magna bibendum '
#           'imperdiet. Nullam orci pede, venenatis non, sodales sed, tincidunt '
#           'eu, felis.\n'
#           '\n'
#           'Fusce posuere felis sed lacus. Morbi sem mauris, laoreet ut, '
#           'rhoncus aliquet, pulvinar sed, nisl. Nunc rhoncus dui vel sem.',
#   'location': 'Philippines',
#   'scientific_name': 'Phalacrocorax brasilianus'},
#  {'common_name': 'Swallow (unidentified)',
#   'id': 33,
#   'info': 'Duis bibendum, felis sed interdum venenatis, turpis enim blandit '
#           'mi, in porttitor pede justo eu massa. Donec dapibus. Duis at velit '
#           'eu est congue elementum.',
#   'location': 'Indonesia',
#   'scientific_name': 'unavailable'},
#  {'common_name': 'Yellow-headed caracara',
#   'id': 34,
#   'info': 'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.\n'
#           '\n'
#           'Fusce consequat. Nulla nisl. Nunc nisl.',
#   'location': 'Canada',
#   'scientific_name': 'Milvago chimachima'},
#  {'common_name': 'Baboon, savanna',
#   'id': 35,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'China',
#   'scientific_name': 'Papio cynocephalus'},
#  {'common_name': 'Roe deer',
#   'id': 36,
#   'info': 'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.',
#   'location': 'Guatemala',
#   'scientific_name': 'Capreolus capreolus'},
#  {'common_name': 'Cormorant, neotropic',
#   'id': 37,
#   'info': 'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.\n'
#           '\n'
#           'Duis aliquam convallis nunc. Proin at turpis a pede posuere '
#           'nonummy. Integer non velit.',
#   'location': 'China',
#   'scientific_name': 'Phalacrocorax brasilianus'},
#  {'common_name': 'Rhinoceros, square-lipped',
#   'id': 38,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.',
#   'location': 'Japan',
#   'scientific_name': 'Ceratotherium simum'},
#  {'common_name': 'Whale, long-finned pilot',
#   'id': 39,
#   'info': 'Aliquam quis turpis eget elit sodales scelerisque. Mauris sit amet '
#           'eros. Suspendisse accumsan tortor quis turpis.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Globicephala melas'},
#  {'common_name': 'Cottonmouth',
#   'id': 40,
#   'info': 'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.\n'
#           '\n'
#           'Curabitur gravida nisi at nibh. In hac habitasse platea dictumst. '
#           'Aliquam augue quam, sollicitudin vitae, consectetuer eget, rutrum '
#           'at, lorem.',
#   'location': 'Philippines',
#   'scientific_name': 'Agkistrodon piscivorus'},
#  {'common_name': 'Brindled gnu',
#   'id': 41,
#   'info': 'Vestibulum ac est lacinia nisi venenatis tristique. Fusce congue, '
#           'diam id ornare imperdiet, sapien urna pretium nisl, ut volutpat '
#           'sapien arcu sed augue. Aliquam erat volutpat.\n'
#           '\n'
#           'In congue. Etiam justo. Etiam pretium iaculis justo.',
#   'location': 'China',
#   'scientific_name': 'Connochaetus taurinus'},
#  {'common_name': 'Carpet python',
#   'id': 42,
#   'info': 'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.\n'
#           '\n'
#           'Curabitur gravida nisi at nibh. In hac habitasse platea dictumst. '
#           'Aliquam augue quam, sollicitudin vitae, consectetuer eget, rutrum '
#           'at, lorem.',
#   'location': 'Afghanistan',
#   'scientific_name': 'Morelia spilotes variegata'},
#  {'common_name': 'Spotted deer',
#   'id': 43,
#   'info': 'Sed ante. Vivamus tortor. Duis mattis egestas metus.',
#   'location': 'Germany',
#   'scientific_name': 'Axis axis'},
#  {'common_name': 'Whale, baleen',
#   'id': 44,
#   'info': 'Duis bibendum. Morbi non quam nec dui luctus rutrum. Nulla tellus.',
#   'location': 'Bulgaria',
#   'scientific_name': 'Eubalaena australis'},
#  {'common_name': 'Eastern indigo snake',
#   'id': 45,
#   'info': 'Quisque id justo sit amet sapien dignissim vestibulum. Vestibulum '
#           'ante ipsum primis in faucibus orci luctus et ultrices posuere '
#           'cubilia Curae; Nulla dapibus dolor vel est. Donec odio justo, '
#           'sollicitudin ut, suscipit a, feugiat et, eros.',
#   'location': 'Indonesia',
#   'scientific_name': 'Drymarchon corias couperi'},
#  {'common_name': 'Rabbit, eastern cottontail',
#   'id': 46,
#   'info': 'Morbi non lectus. Aliquam sit amet diam in magna bibendum '
#           'imperdiet. Nullam orci pede, venenatis non, sodales sed, tincidunt '
#           'eu, felis.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Sylvilagus floridanus'},
#  {'common_name': 'African wild cat',
#   'id': 47,
#   'info': 'Sed sagittis. Nam congue, risus semper porta volutpat, quam pede '
#           'lobortis ligula, sit amet eleifend pede libero quis orci. Nullam '
#           'molestie nibh in lectus.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Felis silvestris lybica'},
#  {'common_name': 'Pelican, brown',
#   'id': 48,
#   'info': 'Integer tincidunt ante vel ipsum. Praesent blandit lacinia erat. '
#           'Vestibulum sed magna at nunc commodo placerat.\n'
#           '\n'
#           'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.',
#   'location': 'Portugal',
#   'scientific_name': 'Pelecanus occidentalis'},
#  {'common_name': 'Steller sea lion',
#   'id': 49,
#   'info': 'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.\n'
#           '\n'
#           'Etiam vel augue. Vestibulum rutrum rutrum neque. Aenean auctor '
#           'gravida sem.',
#   'location': 'China',
#   'scientific_name': 'Eumetopias jubatus'},
#  {'common_name': 'Tawny eagle',
#   'id': 50,
#   'info': 'Quisque id justo sit amet sapien dignissim vestibulum. Vestibulum '
#           'ante ipsum primis in faucibus orci luctus et ultrices posuere '
#           'cubilia Curae; Nulla dapibus dolor vel est. Donec odio justo, '
#           'sollicitudin ut, suscipit a, feugiat et, eros.',
#   'location': 'China',
#   'scientific_name': 'Anitibyx armatus'},
#  {'common_name': 'Pronghorn',
#   'id': 51,
#   'info': 'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.',
#   'location': 'Russia',
#   'scientific_name': 'Antilocapra americana'},
#  {'common_name': 'White-throated monitor',
#   'id': 52,
#   'info': 'Sed ante. Vivamus tortor. Duis mattis egestas metus.',
#   'location': 'China',
#   'scientific_name': 'Varanus albigularis'},
#  {'common_name': 'Turkey vulture',
#   'id': 53,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.\n'
#           '\n'
#           'Vestibulum quam sapien, varius ut, blandit non, interdum in, ante. '
#           'Vestibulum ante ipsum primis in faucibus orci luctus et ultrices '
#           'posuere cubilia Curae; Duis faucibus accumsan odio. Curabitur '
#           'convallis.',
#   'location': 'Malta',
#   'scientific_name': 'Cathartes aura'},
#  {'common_name': 'Bulbul, black-eyed',
#   'id': 54,
#   'info': 'Phasellus in felis. Donec semper sapien a libero. Nam dui.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Pycnonotus barbatus'},
#  {'common_name': 'South African hedgehog',
#   'id': 55,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.\n'
#           '\n'
#           'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.',
#   'location': 'Russia',
#   'scientific_name': 'Erinaceus frontalis'},
#  {'common_name': 'Duck, white-faced whistling',
#   'id': 56,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.',
#   'location': 'China',
#   'scientific_name': 'Dendrocygna viduata'},
#  {'common_name': 'Rufous tree pie',
#   'id': 57,
#   'info': 'Vestibulum ac est lacinia nisi venenatis tristique. Fusce congue, '
#           'diam id ornare imperdiet, sapien urna pretium nisl, ut volutpat '
#           'sapien arcu sed augue. Aliquam erat volutpat.\n'
#           '\n'
#           'In congue. Etiam justo. Etiam pretium iaculis justo.',
#   'location': 'Japan',
#   'scientific_name': 'Dendrocitta vagabunda'},
#  {'common_name': 'White spoonbill',
#   'id': 58,
#   'info': 'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.\n'
#           '\n'
#           'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'Luxembourg',
#   'scientific_name': 'Platalea leucordia'},
#  {'common_name': 'Comb duck',
#   'id': 59,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.\n'
#           '\n'
#           'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.',
#   'location': 'Brazil',
#   'scientific_name': 'Sarkidornis melanotos'},
#  {'common_name': 'Anteater, giant',
#   'id': 60,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.\n'
#           '\n'
#           'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.',
#   'location': 'Peru',
#   'scientific_name': 'Myrmecophaga tridactyla'},
#  {'common_name': 'Steenbuck',
#   'id': 61,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.\n'
#           '\n'
#           'Vestibulum quam sapien, varius ut, blandit non, interdum in, ante. '
#           'Vestibulum ante ipsum primis in faucibus orci luctus et ultrices '
#           'posuere cubilia Curae; Duis faucibus accumsan odio. Curabitur '
#           'convallis.',
#   'location': 'Indonesia',
#   'scientific_name': 'Raphicerus campestris'},
#  {'common_name': 'Elk, Wapiti',
#   'id': 62,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.\n'
#           '\n'
#           'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.',
#   'location': 'Russia',
#   'scientific_name': 'Cervus canadensis'},
#  {'common_name': 'Boubou, southern',
#   'id': 63,
#   'info': 'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.\n'
#           '\n'
#           'Curabitur gravida nisi at nibh. In hac habitasse platea dictumst. '
#           'Aliquam augue quam, sollicitudin vitae, consectetuer eget, rutrum '
#           'at, lorem.',
#   'location': 'China',
#   'scientific_name': 'Laniarius ferrugineus'},
#  {'common_name': "Cat, miner's",
#   'id': 64,
#   'info': 'Duis consequat dui nec nisi volutpat eleifend. Donec ut dolor. '
#           'Morbi vel lectus in quam fringilla rhoncus.',
#   'location': 'Venezuela',
#   'scientific_name': 'Bassariscus astutus'},
#  {'common_name': 'Indian mynah',
#   'id': 65,
#   'info': 'In hac habitasse platea dictumst. Morbi vestibulum, velit id '
#           'pretium iaculis, diam erat fermentum justo, nec condimentum neque '
#           'sapien placerat ante. Nulla justo.',
#   'location': 'South Africa',
#   'scientific_name': 'Acridotheres tristis'},
#  {'common_name': 'Bushpig',
#   'id': 66,
#   'info': 'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.',
#   'location': 'Sweden',
#   'scientific_name': 'Potamochoerus porcus'},
#  {'common_name': 'Fowl, helmeted guinea',
#   'id': 67,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'France',
#   'scientific_name': 'Numida meleagris'},
#  {'common_name': 'Lemur, grey mouse',
#   'id': 68,
#   'info': 'Vestibulum quam sapien, varius ut, blandit non, interdum in, ante. '
#           'Vestibulum ante ipsum primis in faucibus orci luctus et ultrices '
#           'posuere cubilia Curae; Duis faucibus accumsan odio. Curabitur '
#           'convallis.\n'
#           '\n'
#           'Duis consequat dui nec nisi volutpat eleifend. Donec ut dolor. '
#           'Morbi vel lectus in quam fringilla rhoncus.',
#   'location': 'China',
#   'scientific_name': 'Microcebus murinus'},
#  {'common_name': 'Tayra',
#   'id': 69,
#   'info': 'In sagittis dui vel nisl. Duis ac nibh. Fusce lacus purus, aliquet '
#           'at, feugiat non, pretium quis, lectus.\n'
#           '\n'
#           'Suspendisse potenti. In eleifend quam a odio. In hac habitasse '
#           'platea dictumst.',
#   'location': 'Indonesia',
#   'scientific_name': 'Eira barbata'},
#  {'common_name': 'Crab, red lava',
#   'id': 70,
#   'info': 'In quis justo. Maecenas rhoncus aliquam lacus. Morbi quis tortor id '
#           'nulla ultrices aliquet.\n'
#           '\n'
#           'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.',
#   'location': 'Indonesia',
#   'scientific_name': 'Graspus graspus'},
#  {'common_name': 'Baboon, savanna',
#   'id': 71,
#   'info': 'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.',
#   'location': 'Indonesia',
#   'scientific_name': 'Papio cynocephalus'},
#  {'common_name': 'Red-capped cardinal',
#   'id': 72,
#   'info': 'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.\n'
#           '\n'
#           'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.',
#   'location': 'Pakistan',
#   'scientific_name': 'Paroaria gularis'},
#  {'common_name': 'Weaver, chestnut',
#   'id': 73,
#   'info': 'Curabitur gravida nisi at nibh. In hac habitasse platea dictumst. '
#           'Aliquam augue quam, sollicitudin vitae, consectetuer eget, rutrum '
#           'at, lorem.\n'
#           '\n'
#           'Integer tincidunt ante vel ipsum. Praesent blandit lacinia erat. '
#           'Vestibulum sed magna at nunc commodo placerat.',
#   'location': 'Brazil',
#   'scientific_name': 'Ploceus rubiginosus'},
#  {'common_name': 'Fox, north american red',
#   'id': 74,
#   'info': 'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.\n'
#           '\n'
#           'Proin interdum mauris non ligula pellentesque ultrices. Phasellus '
#           'id sapien in sapien iaculis congue. Vivamus metus arcu, adipiscing '
#           'molestie, hendrerit at, vulputate vitae, nisl.',
#   'location': 'China',
#   'scientific_name': 'Vulpes vulpes'},
#  {'common_name': 'Malabar squirrel',
#   'id': 75,
#   'info': 'Fusce posuere felis sed lacus. Morbi sem mauris, laoreet ut, '
#           'rhoncus aliquet, pulvinar sed, nisl. Nunc rhoncus dui vel sem.\n'
#           '\n'
#           'Sed sagittis. Nam congue, risus semper porta volutpat, quam pede '
#           'lobortis ligula, sit amet eleifend pede libero quis orci. Nullam '
#           'molestie nibh in lectus.',
#   'location': 'Argentina',
#   'scientific_name': 'Ratufa indica'},
#  {'common_name': "Swainson's francolin",
#   'id': 76,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.',
#   'location': 'Sweden',
#   'scientific_name': 'Francolinus swainsonii'},
#  {'common_name': 'Crab, sally lightfoot',
#   'id': 77,
#   'info': 'In congue. Etiam justo. Etiam pretium iaculis justo.\n'
#           '\n'
#           'In hac habitasse platea dictumst. Etiam faucibus cursus urna. Ut '
#           'tellus.',
#   'location': 'China',
#   'scientific_name': 'Graspus graspus'},
#  {'common_name': 'Common raccoon',
#   'id': 78,
#   'info': 'Fusce consequat. Nulla nisl. Nunc nisl.',
#   'location': 'Costa Rica',
#   'scientific_name': 'Procyon lotor'},
#  {'common_name': 'Phalarope, grey',
#   'id': 79,
#   'info': 'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.\n'
#           '\n'
#           'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.',
#   'location': 'Bolivia',
#   'scientific_name': 'Phalaropus fulicarius'},
#  {'common_name': 'Lizard, goanna',
#   'id': 80,
#   'info': 'Integer tincidunt ante vel ipsum. Praesent blandit lacinia erat. '
#           'Vestibulum sed magna at nunc commodo placerat.',
#   'location': 'Poland',
#   'scientific_name': 'Varanus sp.'},
#  {'common_name': 'Cereopsis goose',
#   'id': 81,
#   'info': 'Aliquam quis turpis eget elit sodales scelerisque. Mauris sit amet '
#           'eros. Suspendisse accumsan tortor quis turpis.',
#   'location': 'Indonesia',
#   'scientific_name': 'Cereopsis novaehollandiae'},
#  {'common_name': 'Bee-eater, nubian',
#   'id': 82,
#   'info': 'Duis aliquam convallis nunc. Proin at turpis a pede posuere '
#           'nonummy. Integer non velit.\n'
#           '\n'
#           'Donec diam neque, vestibulum eget, vulputate ut, ultrices vel, '
#           'augue. Vestibulum ante ipsum primis in faucibus orci luctus et '
#           'ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum '
#           'aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis '
#           'sapien sapien non mi. Integer ac neque.',
#   'location': 'China',
#   'scientific_name': 'Merops nubicus'},
#  {'common_name': 'Phalarope, northern',
#   'id': 83,
#   'info': 'Duis bibendum. Morbi non quam nec dui luctus rutrum. Nulla tellus.\n'
#           '\n'
#           'In sagittis dui vel nisl. Duis ac nibh. Fusce lacus purus, aliquet '
#           'at, feugiat non, pretium quis, lectus.',
#   'location': 'Poland',
#   'scientific_name': 'Phalaropus lobatus'},
#  {'common_name': 'Coot, red-knobbed',
#   'id': 84,
#   'info': 'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.',
#   'location': 'Indonesia',
#   'scientific_name': 'Fulica cristata'},
#  {'common_name': 'Worm snake (unidentified)',
#   'id': 85,
#   'info': 'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
#           'ipsum. Integer a nibh.\n'
#           '\n'
#           'In quis justo. Maecenas rhoncus aliquam lacus. Morbi quis tortor id '
#           'nulla ultrices aliquet.',
#   'location': 'China',
#   'scientific_name': 'Carphophis sp.'},
#  {'common_name': 'Eastern cottontail rabbit',
#   'id': 86,
#   'info': 'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.\n'
#           '\n'
#           'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.',
#   'location': 'China',
#   'scientific_name': 'Sylvilagus floridanus'},
#  {'common_name': 'Fox, north american red',
#   'id': 87,
#   'info': 'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'Greece',
#   'scientific_name': 'Vulpes vulpes'},
#  {'common_name': 'Bleeding heart monkey',
#   'id': 88,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.\n'
#           '\n'
#           'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.',
#   'location': 'Ukraine',
#   'scientific_name': 'Theropithecus gelada'},
#  {'common_name': 'Lizard (unidentified)',
#   'id': 89,
#   'info': 'Aliquam quis turpis eget elit sodales scelerisque. Mauris sit amet '
#           'eros. Suspendisse accumsan tortor quis turpis.\n'
#           '\n'
#           'Sed ante. Vivamus tortor. Duis mattis egestas metus.',
#   'location': 'Indonesia',
#   'scientific_name': 'unavailable'},
#  {'common_name': 'Cape wild cat',
#   'id': 90,
#   'info': 'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.\n'
#           '\n'
#           'Morbi non lectus. Aliquam sit amet diam in magna bibendum '
#           'imperdiet. Nullam orci pede, venenatis non, sodales sed, tincidunt '
#           'eu, felis.',
#   'location': 'Portugal',
#   'scientific_name': 'Felis libyca'},
#  {'common_name': 'Bulbul, black-fronted',
#   'id': 91,
#   'info': 'Duis bibendum. Morbi non quam nec dui luctus rutrum. Nulla tellus.\n'
#           '\n'
#           'In sagittis dui vel nisl. Duis ac nibh. Fusce lacus purus, aliquet '
#           'at, feugiat non, pretium quis, lectus.',
#   'location': 'Indonesia',
#   'scientific_name': 'Pycnonotus nigricans'},
#  {'common_name': 'Sloth, two-toed tree',
#   'id': 92,
#   'info': 'In congue. Etiam justo. Etiam pretium iaculis justo.\n'
#           '\n'
#           'In hac habitasse platea dictumst. Etiam faucibus cursus urna. Ut '
#           'tellus.',
#   'location': 'Poland',
#   'scientific_name': 'Choloepus hoffmani'},
#  {'common_name': 'Bunting, crested',
#   'id': 93,
#   'info': 'Duis bibendum. Morbi non quam nec dui luctus rutrum. Nulla tellus.',
#   'location': 'Poland',
#   'scientific_name': 'Melophus lathami'},
#  {'common_name': 'Gnu, brindled',
#   'id': 94,
#   'info': 'Sed sagittis. Nam congue, risus semper porta volutpat, quam pede '
#           'lobortis ligula, sit amet eleifend pede libero quis orci. Nullam '
#           'molestie nibh in lectus.\n'
#           '\n'
#           'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'Ireland',
#   'scientific_name': 'Connochaetus taurinus'},
#  {'common_name': 'Capuchin, black-capped',
#   'id': 95,
#   'info': 'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.',
#   'location': 'Russia',
#   'scientific_name': 'Cebus apella'},
#  {'common_name': 'Bee-eater, nubian',
#   'id': 96,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'Indonesia',
#   'scientific_name': 'Merops nubicus'},
#  {'common_name': 'Lemming, collared',
#   'id': 97,
#   'info': 'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.',
#   'location': 'Philippines',
#   'scientific_name': 'Dicrostonyx groenlandicus'},
#  {'common_name': 'Gorilla, western lowland',
#   'id': 98,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.',
#   'location': 'China',
#   'scientific_name': 'Gorilla gorilla'},
#  {'common_name': 'Possum, golden brush-tailed',
#   'id': 99,
#   'info': 'Donec diam neque, vestibulum eget, vulputate ut, ultrices vel, '
#           'augue. Vestibulum ante ipsum primis in faucibus orci luctus et '
#           'ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum '
#           'aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis '
#           'sapien sapien non mi. Integer ac neque.',
#   'location': 'Myanmar',
#   'scientific_name': 'Trichosurus vulpecula'},
#  {'common_name': 'Black rhinoceros',
#   'id': 100,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.',
#   'location': 'Chile',
#   'scientific_name': 'Diceros bicornis'},
#  {'common_name': 'Mongoose, javan gold-spotted',
#   'id': 101,
#   'info': 'Duis aliquam convallis nunc. Proin at turpis a pede posuere '
#           'nonummy. Integer non velit.',
#   'location': 'France',
#   'scientific_name': 'Herpestes javanicus'},
#  {'common_name': 'Black spider monkey',
#   'id': 102,
#   'info': 'Sed sagittis. Nam congue, risus semper porta volutpat, quam pede '
#           'lobortis ligula, sit amet eleifend pede libero quis orci. Nullam '
#           'molestie nibh in lectus.\n'
#           '\n'
#           'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'Portugal',
#   'scientific_name': 'Ateles paniscus'},
#  {'common_name': 'Dove, ring',
#   'id': 103,
#   'info': 'Etiam vel augue. Vestibulum rutrum rutrum neque. Aenean auctor '
#           'gravida sem.\n'
#           '\n'
#           'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.',
#   'location': 'Colombia',
#   'scientific_name': 'Columba palumbus'},
#  {'common_name': 'Blackbird, red-winged',
#   'id': 104,
#   'info': 'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.\n'
#           '\n'
#           'Fusce consequat. Nulla nisl. Nunc nisl.',
#   'location': 'Argentina',
#   'scientific_name': 'Agelaius phoeniceus'},
#  {'common_name': 'Macaw, green-winged',
#   'id': 105,
#   'info': 'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.',
#   'location': 'Poland',
#   'scientific_name': 'Ara chloroptera'},
#  {'common_name': 'Frilled dragon',
#   'id': 106,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.',
#   'location': 'China',
#   'scientific_name': 'Chlamydosaurus kingii'},
#  {'common_name': 'Gull, southern black-backed',
#   'id': 107,
#   'info': 'Duis consequat dui nec nisi volutpat eleifend. Donec ut dolor. '
#           'Morbi vel lectus in quam fringilla rhoncus.\n'
#           '\n'
#           'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.',
#   'location': 'Philippines',
#   'scientific_name': 'Larus dominicanus'},
#  {'common_name': 'Kangaroo, eastern grey',
#   'id': 108,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.\n'
#           '\n'
#           'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.',
#   'location': 'Finland',
#   'scientific_name': 'Macropus giganteus'},
#  {'common_name': 'Red-headed woodpecker',
#   'id': 109,
#   'info': 'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.\n'
#           '\n'
#           'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'China',
#   'scientific_name': 'Melanerpes erythrocephalus'},
#  {'common_name': 'Indian tree pie',
#   'id': 110,
#   'info': 'In sagittis dui vel nisl. Duis ac nibh. Fusce lacus purus, aliquet '
#           'at, feugiat non, pretium quis, lectus.',
#   'location': 'China',
#   'scientific_name': 'Dendrocitta vagabunda'},
#  {'common_name': 'Starling, red-shouldered glossy',
#   'id': 111,
#   'info': 'Cras non velit nec nisi vulputate nonummy. Maecenas tincidunt lacus '
#           'at velit. Vivamus vel nulla eget eros elementum pellentesque.',
#   'location': 'Nigeria',
#   'scientific_name': 'Lamprotornis nitens'},
#  {'common_name': 'Cape white-eye',
#   'id': 112,
#   'info': 'In quis justo. Maecenas rhoncus aliquam lacus. Morbi quis tortor id '
#           'nulla ultrices aliquet.',
#   'location': 'Russia',
#   'scientific_name': 'Zosterops pallidus'},
#  {'common_name': 'Blacksmith plover',
#   'id': 113,
#   'info': 'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.',
#   'location': 'United Arab Emirates',
#   'scientific_name': 'Vanellus armatus'},
#  {'common_name': 'Golden brush-tailed possum',
#   'id': 114,
#   'info': 'Donec diam neque, vestibulum eget, vulputate ut, ultrices vel, '
#           'augue. Vestibulum ante ipsum primis in faucibus orci luctus et '
#           'ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum '
#           'aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis '
#           'sapien sapien non mi. Integer ac neque.',
#   'location': 'Guatemala',
#   'scientific_name': 'Trichosurus vulpecula'},
#  {'common_name': 'Pronghorn',
#   'id': 115,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.\n'
#           '\n'
#           'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.',
#   'location': 'Samoa',
#   'scientific_name': 'Antilocapra americana'},
#  {'common_name': 'Cormorant, flightless',
#   'id': 116,
#   'info': 'Donec diam neque, vestibulum eget, vulputate ut, ultrices vel, '
#           'augue. Vestibulum ante ipsum primis in faucibus orci luctus et '
#           'ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum '
#           'aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis '
#           'sapien sapien non mi. Integer ac neque.\n'
#           '\n'
#           'Duis bibendum. Morbi non quam nec dui luctus rutrum. Nulla tellus.',
#   'location': 'Japan',
#   'scientific_name': 'Nannopterum harrisi'},
#  {'common_name': 'Heron, green',
#   'id': 117,
#   'info': 'Duis bibendum, felis sed interdum venenatis, turpis enim blandit '
#           'mi, in porttitor pede justo eu massa. Donec dapibus. Duis at velit '
#           'eu est congue elementum.',
#   'location': 'Morocco',
#   'scientific_name': 'Butorides striatus'},
#  {'common_name': 'Wallaby, red-necked',
#   'id': 118,
#   'info': 'In hac habitasse platea dictumst. Morbi vestibulum, velit id '
#           'pretium iaculis, diam erat fermentum justo, nec condimentum neque '
#           'sapien placerat ante. Nulla justo.',
#   'location': 'United States',
#   'scientific_name': 'Macropus rufogriseus'},
#  {'common_name': 'Heron, green',
#   'id': 119,
#   'info': 'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'Philippines',
#   'scientific_name': 'Butorides striatus'},
#  {'common_name': 'Great white pelican',
#   'id': 120,
#   'info': 'Sed ante. Vivamus tortor. Duis mattis egestas metus.\n'
#           '\n'
#           'Aenean fermentum. Donec ut mauris eget massa tempor convallis. '
#           'Nulla neque libero, convallis eget, eleifend luctus, ultricies eu, '
#           'nibh.',
#   'location': 'Democratic Republic of the Congo',
#   'scientific_name': 'Pelecans onocratalus'},
#  {'common_name': 'Prairie falcon',
#   'id': 121,
#   'info': 'In hac habitasse platea dictumst. Etiam faucibus cursus urna. Ut '
#           'tellus.',
#   'location': 'France',
#   'scientific_name': 'Falco mexicanus'},
#  {'common_name': 'Toucan, red-billed',
#   'id': 122,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.\n'
#           '\n'
#           'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.',
#   'location': 'United States',
#   'scientific_name': 'Ramphastos tucanus'},
#  {'common_name': 'Godwit, hudsonian',
#   'id': 123,
#   'info': 'Sed ante. Vivamus tortor. Duis mattis egestas metus.',
#   'location': 'Russia',
#   'scientific_name': 'Limosa haemastica'},
#  {'common_name': 'Duiker, gray',
#   'id': 124,
#   'info': 'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.',
#   'location': 'Portugal',
#   'scientific_name': 'Sylvicapra grimma'},
#  {'common_name': "Grant's gazelle",
#   'id': 125,
#   'info': 'Integer tincidunt ante vel ipsum. Praesent blandit lacinia erat. '
#           'Vestibulum sed magna at nunc commodo placerat.\n'
#           '\n'
#           'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.',
#   'location': 'United States',
#   'scientific_name': 'Gazella granti'},
#  {'common_name': 'Painted stork',
#   'id': 126,
#   'info': 'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Mycteria leucocephala'},
#  {'common_name': 'Langur, common',
#   'id': 127,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.\n'
#           '\n'
#           'Vestibulum quam sapien, varius ut, blandit non, interdum in, ante. '
#           'Vestibulum ante ipsum primis in faucibus orci luctus et ultrices '
#           'posuere cubilia Curae; Duis faucibus accumsan odio. Curabitur '
#           'convallis.',
#   'location': 'Costa Rica',
#   'scientific_name': 'Semnopithecus entellus'},
#  {'common_name': 'Striped dolphin',
#   'id': 128,
#   'info': 'Curabitur in libero ut massa volutpat convallis. Morbi odio odio, '
#           'elementum eu, interdum eu, tincidunt in, leo. Maecenas pulvinar '
#           'lobortis est.\n'
#           '\n'
#           'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.',
#   'location': 'Ireland',
#   'scientific_name': 'Stenella coeruleoalba'},
#  {'common_name': 'Duck, mountain',
#   'id': 129,
#   'info': 'Duis consequat dui nec nisi volutpat eleifend. Donec ut dolor. '
#           'Morbi vel lectus in quam fringilla rhoncus.',
#   'location': 'Russia',
#   'scientific_name': 'Hymenolaimus malacorhynchus'},
#  {'common_name': 'Striated heron',
#   'id': 130,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.\n'
#           '\n'
#           'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
#           'ipsum. Integer a nibh.',
#   'location': 'Portugal',
#   'scientific_name': 'Butorides striatus'},
#  {'common_name': 'Native cat',
#   'id': 131,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.\n'
#           '\n'
#           'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
# ...
#   'id': 959,
#   'info': 'Proin interdum mauris non ligula pellentesque ultrices. Phasellus '
#           'id sapien in sapien iaculis congue. Vivamus metus arcu, adipiscing '
#           'molestie, hendrerit at, vulputate vitae, nisl.',
#   'location': 'Tajikistan',
#   'scientific_name': 'Psophia viridis'},
#  {'common_name': 'Australian pelican',
#   'id': 960,
#   'info': 'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.',
#   'location': 'Indonesia',
#   'scientific_name': 'Pelecanus conspicillatus'},
#  {'common_name': 'Antelope, roan',
#   'id': 961,
#   'info': 'Aliquam quis turpis eget elit sodales scelerisque. Mauris sit amet '
#           'eros. Suspendisse accumsan tortor quis turpis.\n'
#           '\n'
#           'Sed ante. Vivamus tortor. Duis mattis egestas metus.',
#   'location': 'Sweden',
#   'scientific_name': 'Hippotragus equinus'},
#  {'common_name': 'Bonnet macaque',
#   'id': 962,
#   'info': 'In hac habitasse platea dictumst. Etiam faucibus cursus urna. Ut '
#           'tellus.\n'
#           '\n'
#           'Nulla ut erat id mauris vulputate elementum. Nullam varius. Nulla '
#           'facilisi.',
#   'location': 'Indonesia',
#   'scientific_name': 'Macaca radiata'},
#  {'common_name': 'Gray rhea',
#   'id': 963,
#   'info': 'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.\n'
#           '\n'
#           'Morbi non lectus. Aliquam sit amet diam in magna bibendum '
#           'imperdiet. Nullam orci pede, venenatis non, sodales sed, tincidunt '
#           'eu, felis.',
#   'location': 'Japan',
#   'scientific_name': 'Rhea americana'},
#  {'common_name': 'Jungle cat',
#   'id': 964,
#   'info': 'Duis consequat dui nec nisi volutpat eleifend. Donec ut dolor. '
#           'Morbi vel lectus in quam fringilla rhoncus.',
#   'location': 'Poland',
#   'scientific_name': 'Felis chaus'},
#  {'common_name': 'Cormorant, javanese',
#   'id': 965,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.\n'
#           '\n'
#           'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
#           'ipsum. Integer a nibh.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Phalacrocorax niger'},
#  {'common_name': 'Black bear',
#   'id': 966,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.\n'
#           '\n'
#           'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
#           'ipsum. Integer a nibh.',
#   'location': 'Canada',
#   'scientific_name': 'Ursus americanus'},
#  {'common_name': 'Pronghorn',
#   'id': 967,
#   'info': 'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.\n'
#           '\n'
#           'Fusce consequat. Nulla nisl. Nunc nisl.',
#   'location': 'China',
#   'scientific_name': 'Antilocapra americana'},
#  {'common_name': 'Flamingo, chilean',
#   'id': 968,
#   'info': 'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.\n'
#           '\n'
#           'Etiam vel augue. Vestibulum rutrum rutrum neque. Aenean auctor '
#           'gravida sem.',
#   'location': 'Kazakhstan',
#   'scientific_name': 'Phoenicopterus chilensis'},
#  {'common_name': 'Blue catfish',
#   'id': 969,
#   'info': 'Cras non velit nec nisi vulputate nonummy. Maecenas tincidunt lacus '
#           'at velit. Vivamus vel nulla eget eros elementum pellentesque.',
#   'location': 'Portugal',
#   'scientific_name': 'Ictalurus furcatus'},
#  {'common_name': 'Indian jackal',
#   'id': 970,
#   'info': 'Proin interdum mauris non ligula pellentesque ultrices. Phasellus '
#           'id sapien in sapien iaculis congue. Vivamus metus arcu, adipiscing '
#           'molestie, hendrerit at, vulputate vitae, nisl.\n'
#           '\n'
#           'Aenean lectus. Pellentesque eget nunc. Donec quis orci eget orci '
#           'vehicula condimentum.',
#   'location': 'Indonesia',
#   'scientific_name': 'Canis aureus'},
#  {'common_name': 'Godwit, hudsonian',
#   'id': 971,
#   'info': 'Quisque porta volutpat erat. Quisque erat eros, viverra eget, '
#           'congue eget, semper rutrum, nulla. Nunc purus.',
#   'location': 'Indonesia',
#   'scientific_name': 'Limosa haemastica'},
#  {'common_name': 'Gnu, brindled',
#   'id': 972,
#   'info': 'Quisque id justo sit amet sapien dignissim vestibulum. Vestibulum '
#           'ante ipsum primis in faucibus orci luctus et ultrices posuere '
#           'cubilia Curae; Nulla dapibus dolor vel est. Donec odio justo, '
#           'sollicitudin ut, suscipit a, feugiat et, eros.',
#   'location': 'Uganda',
#   'scientific_name': 'Connochaetus taurinus'},
#  {'common_name': 'Asian red fox',
#   'id': 973,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.\n'
#           '\n'
#           'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
#           'ipsum. Integer a nibh.',
#   'location': 'China',
#   'scientific_name': 'Vulpes vulpes'},
#  {'common_name': 'Oystercatcher, blackish',
#   'id': 974,
#   'info': 'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.',
#   'location': 'China',
#   'scientific_name': 'Haematopus ater'},
#  {'common_name': 'Carmine bee-eater',
#   'id': 975,
#   'info': 'Integer tincidunt ante vel ipsum. Praesent blandit lacinia erat. '
#           'Vestibulum sed magna at nunc commodo placerat.\n'
#           '\n'
#           'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.',
#   'location': 'Micronesia',
#   'scientific_name': 'Merops nubicus'},
#  {'common_name': 'Blue wildebeest',
#   'id': 976,
#   'info': 'Duis aliquam convallis nunc. Proin at turpis a pede posuere '
#           'nonummy. Integer non velit.\n'
#           '\n'
#           'Donec diam neque, vestibulum eget, vulputate ut, ultrices vel, '
#           'augue. Vestibulum ante ipsum primis in faucibus orci luctus et '
#           'ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum '
#           'aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis '
#           'sapien sapien non mi. Integer ac neque.',
#   'location': 'China',
#   'scientific_name': 'Connochaetus taurinus'},
#  {'common_name': 'Weaver, red-billed buffalo',
#   'id': 977,
#   'info': 'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.\n'
#           '\n'
#           'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.',
#   'location': 'China',
#   'scientific_name': 'Bubalornis niger'},
#  {'common_name': 'Cheetah',
#   'id': 978,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.',
#   'location': 'China',
#   'scientific_name': 'Acinynox jubatus'},
#  {'common_name': 'Yellow-crowned night heron',
#   'id': 979,
#   'info': 'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.',
#   'location': 'China',
#   'scientific_name': 'Nyctanassa violacea'},
#  {'common_name': 'Owl, white-browed',
#   'id': 980,
#   'info': 'Duis bibendum, felis sed interdum venenatis, turpis enim blandit '
#           'mi, in porttitor pede justo eu massa. Donec dapibus. Duis at velit '
#           'eu est congue elementum.\n'
#           '\n'
#           'In hac habitasse platea dictumst. Morbi vestibulum, velit id '
#           'pretium iaculis, diam erat fermentum justo, nec condimentum neque '
#           'sapien placerat ante. Nulla justo.',
#   'location': 'Indonesia',
#   'scientific_name': 'Ninox superciliaris'},
#  {'common_name': "Miner's cat",
#   'id': 981,
#   'info': 'Phasellus in felis. Donec semper sapien a libero. Nam dui.',
#   'location': 'Bolivia',
#   'scientific_name': 'Bassariscus astutus'},
#  {'common_name': 'Lizard (unidentified)',
#   'id': 982,
#   'info': 'Proin interdum mauris non ligula pellentesque ultrices. Phasellus '
#           'id sapien in sapien iaculis congue. Vivamus metus arcu, adipiscing '
#           'molestie, hendrerit at, vulputate vitae, nisl.',
#   'location': 'Indonesia',
#   'scientific_name': 'unavailable'},
#  {'common_name': 'Turaco, violet-crested',
#   'id': 983,
#   'info': 'Donec diam neque, vestibulum eget, vulputate ut, ultrices vel, '
#           'augue. Vestibulum ante ipsum primis in faucibus orci luctus et '
#           'ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum '
#           'aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis '
#           'sapien sapien non mi. Integer ac neque.',
#   'location': 'Argentina',
#   'scientific_name': 'Tauraco porphyrelophus'},
#  {'common_name': 'Sparrow, rufous-collared',
#   'id': 984,
#   'info': 'Fusce posuere felis sed lacus. Morbi sem mauris, laoreet ut, '
#           'rhoncus aliquet, pulvinar sed, nisl. Nunc rhoncus dui vel sem.',
#   'location': 'China',
#   'scientific_name': 'Zonotrichia capensis'},
#  {'common_name': 'Pale-throated three-toed sloth',
#   'id': 985,
#   'info': 'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.',
#   'location': 'Iran',
#   'scientific_name': 'Bradypus tridactylus'},
#  {'common_name': 'White-necked raven',
#   'id': 986,
#   'info': 'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.',
#   'location': 'Ukraine',
#   'scientific_name': 'Corvus albicollis'},
#  {'common_name': 'Black-capped chickadee',
#   'id': 987,
#   'info': 'Sed ante. Vivamus tortor. Duis mattis egestas metus.\n'
#           '\n'
#           'Aenean fermentum. Donec ut mauris eget massa tempor convallis. '
#           'Nulla neque libero, convallis eget, eleifend luctus, ultricies eu, '
#           'nibh.',
#   'location': 'Poland',
#   'scientific_name': 'Parus atricapillus'},
#  {'common_name': 'Yellow mongoose',
#   'id': 988,
#   'info': 'Aenean fermentum. Donec ut mauris eget massa tempor convallis. '
#           'Nulla neque libero, convallis eget, eleifend luctus, ultricies eu, '
#           'nibh.\n'
#           '\n'
#           'Quisque id justo sit amet sapien dignissim vestibulum. Vestibulum '
#           'ante ipsum primis in faucibus orci luctus et ultrices posuere '
#           'cubilia Curae; Nulla dapibus dolor vel est. Donec odio justo, '
#           'sollicitudin ut, suscipit a, feugiat et, eros.',
#   'location': 'Ireland',
#   'scientific_name': 'Cynictis penicillata'},
#  {'common_name': 'Greater blue-eared starling',
#   'id': 989,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.\n'
#           '\n'
#           'Vestibulum quam sapien, varius ut, blandit non, interdum in, ante. '
#           'Vestibulum ante ipsum primis in faucibus orci luctus et ultrices '
#           'posuere cubilia Curae; Duis faucibus accumsan odio. Curabitur '
#           'convallis.',
#   'location': 'Indonesia',
#   'scientific_name': 'Lamprotornis chalybaeus'},
#  {'common_name': 'Kangaroo, jungle',
#   'id': 990,
#   'info': 'Nam ultrices, libero non mattis pulvinar, nulla pede ullamcorper '
#           'augue, a suscipit nulla elit ac nulla. Sed vel enim sit amet nunc '
#           'viverra dapibus. Nulla suscipit ligula in lacus.\n'
#           '\n'
#           'Curabitur at ipsum ac tellus semper interdum. Mauris ullamcorper '
#           'purus sit amet nulla. Quisque arcu libero, rutrum ac, lobortis vel, '
#           'dapibus at, diam.',
#   'location': 'Sweden',
#   'scientific_name': 'Macropus agilis'},
#  {'common_name': 'White-necked stork',
#   'id': 991,
#   'info': 'Morbi non lectus. Aliquam sit amet diam in magna bibendum '
#           'imperdiet. Nullam orci pede, venenatis non, sodales sed, tincidunt '
#           'eu, felis.\n'
#           '\n'
#           'Fusce posuere felis sed lacus. Morbi sem mauris, laoreet ut, '
#           'rhoncus aliquet, pulvinar sed, nisl. Nunc rhoncus dui vel sem.',
#   'location': 'Oman',
#   'scientific_name': 'Ciconia episcopus'},
#  {'common_name': 'Pacific gull',
#   'id': 992,
#   'info': 'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.',
#   'location': 'Cameroon',
#   'scientific_name': 'Gabianus pacificus'},
#  {'common_name': 'Gnu, brindled',
#   'id': 993,
#   'info': 'Suspendisse potenti. In eleifend quam a odio. In hac habitasse '
#           'platea dictumst.\n'
#           '\n'
#           'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.',
#   'location': 'China',
#   'scientific_name': 'Connochaetus taurinus'},
#  {'common_name': 'Bettong, brush-tailed',
#   'id': 994,
#   'info': 'Curabitur at ipsum ac tellus semper interdum. Mauris ullamcorper '
#           'purus sit amet nulla. Quisque arcu libero, rutrum ac, lobortis vel, '
#           'dapibus at, diam.',
#   'location': 'Norway',
#   'scientific_name': 'Bettongia penicillata'},
#  {'common_name': 'Screamer, crested',
#   'id': 995,
#   'info': 'Etiam vel augue. Vestibulum rutrum rutrum neque. Aenean auctor '
#           'gravida sem.\n'
#           '\n'
#           'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.',
#   'location': 'Ireland',
#   'scientific_name': 'Chauna torquata'},
#  {'common_name': 'Savannah deer (unidentified)',
#   'id': 996,
#   'info': 'In quis justo. Maecenas rhoncus aliquam lacus. Morbi quis tortor id '
#           'nulla ultrices aliquet.',
#   'location': 'Portugal',
#   'scientific_name': 'unavailable'},
#  {'common_name': 'Goose, canada',
#   'id': 997,
#   'info': 'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.\n'
#           '\n'
#           'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Branta canadensis'},
#  {'common_name': 'White-nosed coatimundi',
#   'id': 998,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.',
#   'location': 'China',
#   'scientific_name': 'Nasua narica'},
#  {'common_name': 'Rattlesnake, eastern diamondback',
#   'id': 999,
#   'info': 'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'Poland',
#   'scientific_name': 'Crotalus adamanteus'},
#  {'common_name': 'Sloth, two-toed tree',
#   'id': 1000,
#   'info': 'Curabitur in libero ut massa volutpat convallis. Morbi odio odio, '
#           'elementum eu, interdum eu, tincidunt in, leo. Maecenas pulvinar '
#           'lobortis est.\n'
#           '\n'
#           'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.',
#   'location': 'United States',
#   'scientific_name': 'Choloepus hoffmani'}]

# %%
response_json[len(response_json)-1]
# Out:
# {'id': 1000,
#  'common_name': 'Sloth, two-toed tree',
#  'scientific_name': 'Choloepus hoffmani',
#  'info': 'Curabitur in libero ut massa volutpat convallis. Morbi odio odio, elementum eu, interdum eu, tincidunt in, leo. Maecenas pulvinar lobortis est.\n\nPhasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien cursus vestibulum.',
#  'location': 'United States'}

# %%
# Print the first and last articles
pprint(f"The first video is{response_json[0]}.")
pprint(f"The last video is {response_json[-1]}.")
# Out:
# ("The first video is{'id': 1, 'common_name': 'Tiger cat', 'scientific_name': "
#  "'Dasyurus maculatus', 'info': 'Curabitur at ipsum ac tellus semper interdum. "
#  'Mauris ullamcorper purus sit amet nulla. Quisque arcu libero, rutrum ac, '
#  "lobortis vel, dapibus at, diam.', 'location': 'Russia'}.")
# ("The last video is {'id': 1000, 'common_name': 'Sloth, two-toed tree', "
#  "'scientific_name': 'Choloepus hoffmani', 'info': 'Curabitur in libero ut "
#  'massa volutpat convallis. Morbi odio odio, elementum eu, interdum eu, '
#  'tincidunt in, leo. Maecenas pulvinar lobortis est.\\n\\nPhasellus sit amet '
#  "erat. Nulla tempus. Vivamus in felis eu sapien cursus vestibulum.', "
#  "'location': 'United States'}.")

# %%
# Print the first and last articles
pprint(f"The first video is{response_json[0]}.")
pprint(f"The last video is {response_json[-1]}.")
# Out:
# ("The first video is{'id': 1, 'common_name': 'Tiger cat', 'scientific_name': "
#  "'Dasyurus maculatus', 'info': 'Curabitur at ipsum ac tellus semper interdum. "
#  'Mauris ullamcorper purus sit amet nulla. Quisque arcu libero, rutrum ac, '
#  "lobortis vel, dapibus at, diam.', 'location': 'Russia'}.")
# ("The last video is {'id': 1000, 'common_name': 'Sloth, two-toed tree', "
#  "'scientific_name': 'Choloepus hoffmani', 'info': 'Curabitur in libero ut "
#  'massa volutpat convallis. Morbi odio odio, elementum eu, interdum eu, '
#  'tincidunt in, leo. Maecenas pulvinar lobortis est.\\n\\nPhasellus sit amet '
#  "erat. Nulla tempus. Vivamus in felis eu sapien cursus vestibulum.', "
#  "'location': 'United States'}.")

# %%
# Dependencies
import json
import requests
from pprint import pprint

# %%
# Specify the URL
url = 'https://2u-data-curriculum-team.s3.amazonaws.com/dataviz-classroom/v1.1/06-Python-APIs/request_review.json'

# %%
# Make the request and store the response
response = requests.get(url)

# %%
#JSONify the response
response_json = response.json()
pprint(response_json)
# Out:
# [{'common_name': 'Tiger cat',
#   'id': 1,
#   'info': 'Curabitur at ipsum ac tellus semper interdum. Mauris ullamcorper '
#           'purus sit amet nulla. Quisque arcu libero, rutrum ac, lobortis vel, '
#           'dapibus at, diam.',
#   'location': 'Russia',
#   'scientific_name': 'Dasyurus maculatus'},
#  {'common_name': 'Crab-eating fox',
#   'id': 2,
#   'info': 'Vestibulum ac est lacinia nisi venenatis tristique. Fusce congue, '
#           'diam id ornare imperdiet, sapien urna pretium nisl, ut volutpat '
#           'sapien arcu sed augue. Aliquam erat volutpat.\n'
#           '\n'
#           'In congue. Etiam justo. Etiam pretium iaculis justo.',
#   'location': 'Sweden',
#   'scientific_name': 'Dusicyon thous'},
#  {'common_name': 'Pelican, brown',
#   'id': 3,
#   'info': 'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.\n'
#           '\n'
#           'Proin interdum mauris non ligula pellentesque ultrices. Phasellus '
#           'id sapien in sapien iaculis congue. Vivamus metus arcu, adipiscing '
#           'molestie, hendrerit at, vulputate vitae, nisl.',
#   'location': 'China',
#   'scientific_name': 'Pelecanus occidentalis'},
#  {'common_name': 'Mongoose, banded',
#   'id': 4,
#   'info': 'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.',
#   'location': 'Armenia',
#   'scientific_name': 'Mungos mungo'},
#  {'common_name': 'Chital',
#   'id': 5,
#   'info': 'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'Portugal',
#   'scientific_name': 'Axis axis'},
#  {'common_name': 'Skunk, western spotted',
#   'id': 6,
#   'info': 'Quisque id justo sit amet sapien dignissim vestibulum. Vestibulum '
#           'ante ipsum primis in faucibus orci luctus et ultrices posuere '
#           'cubilia Curae; Nulla dapibus dolor vel est. Donec odio justo, '
#           'sollicitudin ut, suscipit a, feugiat et, eros.',
#   'location': 'Myanmar',
#   'scientific_name': 'Spilogale gracilis'},
#  {'common_name': 'Zorilla',
#   'id': 7,
#   'info': 'Fusce consequat. Nulla nisl. Nunc nisl.\n'
#           '\n'
#           'Duis bibendum, felis sed interdum venenatis, turpis enim blandit '
#           'mi, in porttitor pede justo eu massa. Donec dapibus. Duis at velit '
#           'eu est congue elementum.',
#   'location': 'China',
#   'scientific_name': 'Ictonyx striatus'},
#  {'common_name': 'Western pygmy possum',
#   'id': 8,
#   'info': 'In quis justo. Maecenas rhoncus aliquam lacus. Morbi quis tortor id '
#           'nulla ultrices aliquet.\n'
#           '\n'
#           'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.',
#   'location': 'Croatia',
#   'scientific_name': 'Cercatetus concinnus'},
#  {'common_name': 'Wambenger, red-tailed',
#   'id': 9,
#   'info': 'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.\n'
#           '\n'
#           'Curabitur gravida nisi at nibh. In hac habitasse platea dictumst. '
#           'Aliquam augue quam, sollicitudin vitae, consectetuer eget, rutrum '
#           'at, lorem.',
#   'location': 'Sweden',
#   'scientific_name': 'Phascogale calura'},
#  {'common_name': 'Otter, canadian river',
#   'id': 10,
#   'info': 'Integer tincidunt ante vel ipsum. Praesent blandit lacinia erat. '
#           'Vestibulum sed magna at nunc commodo placerat.\n'
#           '\n'
#           'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.',
#   'location': 'China',
#   'scientific_name': 'Lutra canadensis'},
#  {'common_name': 'Brown antechinus',
#   'id': 11,
#   'info': 'In hac habitasse platea dictumst. Morbi vestibulum, velit id '
#           'pretium iaculis, diam erat fermentum justo, nec condimentum neque '
#           'sapien placerat ante. Nulla justo.\n'
#           '\n'
#           'Aliquam quis turpis eget elit sodales scelerisque. Mauris sit amet '
#           'eros. Suspendisse accumsan tortor quis turpis.',
#   'location': 'China',
#   'scientific_name': 'Antechinus flavipes'},
#  {'common_name': 'Tortoise, galapagos',
#   'id': 12,
#   'info': 'In hac habitasse platea dictumst. Morbi vestibulum, velit id '
#           'pretium iaculis, diam erat fermentum justo, nec condimentum neque '
#           'sapien placerat ante. Nulla justo.',
#   'location': 'China',
#   'scientific_name': 'Geochelone elephantopus'},
#  {'common_name': "Coke's hartebeest",
#   'id': 13,
#   'info': 'Curabitur in libero ut massa volutpat convallis. Morbi odio odio, '
#           'elementum eu, interdum eu, tincidunt in, leo. Maecenas pulvinar '
#           'lobortis est.',
#   'location': 'Croatia',
#   'scientific_name': 'Alcelaphus buselaphus cokii'},
#  {'common_name': 'Thrasher, curve-billed',
#   'id': 14,
#   'info': 'In hac habitasse platea dictumst. Etiam faucibus cursus urna. Ut '
#           'tellus.',
#   'location': 'France',
#   'scientific_name': 'Toxostoma curvirostre'},
#  {'common_name': 'Pine siskin',
#   'id': 15,
#   'info': 'Proin leo odio, porttitor id, consequat in, consequat ut, nulla. '
#           'Sed accumsan felis. Ut at dolor quis odio consequat varius.\n'
#           '\n'
#           'Integer ac leo. Pellentesque ultrices mattis odio. Donec vitae '
#           'nisi.',
#   'location': 'Brazil',
#   'scientific_name': 'Carduelis pinus'},
#  {'common_name': 'Owl, madagascar hawk',
#   'id': 16,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'Slovenia',
#   'scientific_name': 'Ninox superciliaris'},
#  {'common_name': 'Blue and gold macaw',
#   'id': 17,
#   'info': 'Aenean fermentum. Donec ut mauris eget massa tempor convallis. '
#           'Nulla neque libero, convallis eget, eleifend luctus, ultricies eu, '
#           'nibh.',
#   'location': 'Philippines',
#   'scientific_name': 'Ara ararauna'},
#  {'common_name': 'Cape Barren goose',
#   'id': 18,
#   'info': 'Aliquam quis turpis eget elit sodales scelerisque. Mauris sit amet '
#           'eros. Suspendisse accumsan tortor quis turpis.',
#   'location': 'Cameroon',
#   'scientific_name': 'Cereopsis novaehollandiae'},
#  {'common_name': 'Canadian tiger swallowtail butterfly',
#   'id': 19,
#   'info': 'Nulla ut erat id mauris vulputate elementum. Nullam varius. Nulla '
#           'facilisi.\n'
#           '\n'
#           'Cras non velit nec nisi vulputate nonummy. Maecenas tincidunt lacus '
#           'at velit. Vivamus vel nulla eget eros elementum pellentesque.',
#   'location': 'China',
#   'scientific_name': 'Papilio canadensis'},
#  {'common_name': 'Agouti',
#   'id': 20,
#   'info': 'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.\n'
#           '\n'
#           'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.',
#   'location': 'China',
#   'scientific_name': 'Dasyprocta leporina'},
#  {'common_name': 'Klipspringer',
#   'id': 21,
#   'info': 'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
#           'ipsum. Integer a nibh.\n'
#           '\n'
#           'In quis justo. Maecenas rhoncus aliquam lacus. Morbi quis tortor id '
#           'nulla ultrices aliquet.',
#   'location': 'United States',
#   'scientific_name': 'Oreotragus oreotragus'},
#  {'common_name': 'Woodrat (unidentified)',
#   'id': 22,
#   'info': 'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.\n'
#           '\n'
#           'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.',
#   'location': 'Panama',
#   'scientific_name': 'Neotoma sp.'},
#  {'common_name': 'Nelson ground squirrel',
#   'id': 23,
#   'info': 'Proin interdum mauris non ligula pellentesque ultrices. Phasellus '
#           'id sapien in sapien iaculis congue. Vivamus metus arcu, adipiscing '
#           'molestie, hendrerit at, vulputate vitae, nisl.',
#   'location': 'Colombia',
#   'scientific_name': 'Ammospermophilus nelsoni'},
#  {'common_name': 'African darter',
#   'id': 24,
#   'info': 'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.\n'
#           '\n'
#           'Fusce consequat. Nulla nisl. Nunc nisl.',
#   'location': 'China',
#   'scientific_name': 'Anhinga rufa'},
#  {'common_name': 'Mississippi alligator',
#   'id': 25,
#   'info': 'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.\n'
#           '\n'
#           'Morbi non lectus. Aliquam sit amet diam in magna bibendum '
#           'imperdiet. Nullam orci pede, venenatis non, sodales sed, tincidunt '
#           'eu, felis.',
#   'location': 'Spain',
#   'scientific_name': 'Alligator mississippiensis'},
#  {'common_name': 'Plains zebra',
#   'id': 26,
#   'info': 'Quisque porta volutpat erat. Quisque erat eros, viverra eget, '
#           'congue eget, semper rutrum, nulla. Nunc purus.\n'
#           '\n'
#           'Phasellus in felis. Donec semper sapien a libero. Nam dui.',
#   'location': 'Sweden',
#   'scientific_name': 'Equus burchelli'},
#  {'common_name': 'Sea birds (unidentified)',
#   'id': 27,
#   'info': 'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.',
#   'location': 'North Korea',
#   'scientific_name': 'unavailable'},
#  {'common_name': "Squirrel, richardson's ground",
#   'id': 28,
#   'info': 'Suspendisse potenti. In eleifend quam a odio. In hac habitasse '
#           'platea dictumst.\n'
#           '\n'
#           'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.',
#   'location': 'China',
#   'scientific_name': 'Spermophilus richardsonii'},
#  {'common_name': 'Otter, small-clawed',
#   'id': 29,
#   'info': 'Sed sagittis. Nam congue, risus semper porta volutpat, quam pede '
#           'lobortis ligula, sit amet eleifend pede libero quis orci. Nullam '
#           'molestie nibh in lectus.\n'
#           '\n'
#           'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'Indonesia',
#   'scientific_name': 'Aonyx cinerea'},
#  {'common_name': 'Mongoose, javan gold-spotted',
#   'id': 30,
#   'info': 'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.',
#   'location': 'China',
#   'scientific_name': 'Herpestes javanicus'},
#  {'common_name': 'Water legaan',
#   'id': 31,
#   'info': 'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.\n'
#           '\n'
#           'Curabitur gravida nisi at nibh. In hac habitasse platea dictumst. '
#           'Aliquam augue quam, sollicitudin vitae, consectetuer eget, rutrum '
#           'at, lorem.',
#   'location': 'United States',
#   'scientific_name': 'Varanus salvator'},
#  {'common_name': 'Neotropic cormorant',
#   'id': 32,
#   'info': 'Morbi non lectus. Aliquam sit amet diam in magna bibendum '
#           'imperdiet. Nullam orci pede, venenatis non, sodales sed, tincidunt '
#           'eu, felis.\n'
#           '\n'
#           'Fusce posuere felis sed lacus. Morbi sem mauris, laoreet ut, '
#           'rhoncus aliquet, pulvinar sed, nisl. Nunc rhoncus dui vel sem.',
#   'location': 'Philippines',
#   'scientific_name': 'Phalacrocorax brasilianus'},
#  {'common_name': 'Swallow (unidentified)',
#   'id': 33,
#   'info': 'Duis bibendum, felis sed interdum venenatis, turpis enim blandit '
#           'mi, in porttitor pede justo eu massa. Donec dapibus. Duis at velit '
#           'eu est congue elementum.',
#   'location': 'Indonesia',
#   'scientific_name': 'unavailable'},
#  {'common_name': 'Yellow-headed caracara',
#   'id': 34,
#   'info': 'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.\n'
#           '\n'
#           'Fusce consequat. Nulla nisl. Nunc nisl.',
#   'location': 'Canada',
#   'scientific_name': 'Milvago chimachima'},
#  {'common_name': 'Baboon, savanna',
#   'id': 35,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'China',
#   'scientific_name': 'Papio cynocephalus'},
#  {'common_name': 'Roe deer',
#   'id': 36,
#   'info': 'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.',
#   'location': 'Guatemala',
#   'scientific_name': 'Capreolus capreolus'},
#  {'common_name': 'Cormorant, neotropic',
#   'id': 37,
#   'info': 'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.\n'
#           '\n'
#           'Duis aliquam convallis nunc. Proin at turpis a pede posuere '
#           'nonummy. Integer non velit.',
#   'location': 'China',
#   'scientific_name': 'Phalacrocorax brasilianus'},
#  {'common_name': 'Rhinoceros, square-lipped',
#   'id': 38,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.',
#   'location': 'Japan',
#   'scientific_name': 'Ceratotherium simum'},
#  {'common_name': 'Whale, long-finned pilot',
#   'id': 39,
#   'info': 'Aliquam quis turpis eget elit sodales scelerisque. Mauris sit amet '
#           'eros. Suspendisse accumsan tortor quis turpis.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Globicephala melas'},
#  {'common_name': 'Cottonmouth',
#   'id': 40,
#   'info': 'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.\n'
#           '\n'
#           'Curabitur gravida nisi at nibh. In hac habitasse platea dictumst. '
#           'Aliquam augue quam, sollicitudin vitae, consectetuer eget, rutrum '
#           'at, lorem.',
#   'location': 'Philippines',
#   'scientific_name': 'Agkistrodon piscivorus'},
#  {'common_name': 'Brindled gnu',
#   'id': 41,
#   'info': 'Vestibulum ac est lacinia nisi venenatis tristique. Fusce congue, '
#           'diam id ornare imperdiet, sapien urna pretium nisl, ut volutpat '
#           'sapien arcu sed augue. Aliquam erat volutpat.\n'
#           '\n'
#           'In congue. Etiam justo. Etiam pretium iaculis justo.',
#   'location': 'China',
#   'scientific_name': 'Connochaetus taurinus'},
#  {'common_name': 'Carpet python',
#   'id': 42,
#   'info': 'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.\n'
#           '\n'
#           'Curabitur gravida nisi at nibh. In hac habitasse platea dictumst. '
#           'Aliquam augue quam, sollicitudin vitae, consectetuer eget, rutrum '
#           'at, lorem.',
#   'location': 'Afghanistan',
#   'scientific_name': 'Morelia spilotes variegata'},
#  {'common_name': 'Spotted deer',
#   'id': 43,
#   'info': 'Sed ante. Vivamus tortor. Duis mattis egestas metus.',
#   'location': 'Germany',
#   'scientific_name': 'Axis axis'},
#  {'common_name': 'Whale, baleen',
#   'id': 44,
#   'info': 'Duis bibendum. Morbi non quam nec dui luctus rutrum. Nulla tellus.',
#   'location': 'Bulgaria',
#   'scientific_name': 'Eubalaena australis'},
#  {'common_name': 'Eastern indigo snake',
#   'id': 45,
#   'info': 'Quisque id justo sit amet sapien dignissim vestibulum. Vestibulum '
#           'ante ipsum primis in faucibus orci luctus et ultrices posuere '
#           'cubilia Curae; Nulla dapibus dolor vel est. Donec odio justo, '
#           'sollicitudin ut, suscipit a, feugiat et, eros.',
#   'location': 'Indonesia',
#   'scientific_name': 'Drymarchon corias couperi'},
#  {'common_name': 'Rabbit, eastern cottontail',
#   'id': 46,
#   'info': 'Morbi non lectus. Aliquam sit amet diam in magna bibendum '
#           'imperdiet. Nullam orci pede, venenatis non, sodales sed, tincidunt '
#           'eu, felis.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Sylvilagus floridanus'},
#  {'common_name': 'African wild cat',
#   'id': 47,
#   'info': 'Sed sagittis. Nam congue, risus semper porta volutpat, quam pede '
#           'lobortis ligula, sit amet eleifend pede libero quis orci. Nullam '
#           'molestie nibh in lectus.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Felis silvestris lybica'},
#  {'common_name': 'Pelican, brown',
#   'id': 48,
#   'info': 'Integer tincidunt ante vel ipsum. Praesent blandit lacinia erat. '
#           'Vestibulum sed magna at nunc commodo placerat.\n'
#           '\n'
#           'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.',
#   'location': 'Portugal',
#   'scientific_name': 'Pelecanus occidentalis'},
#  {'common_name': 'Steller sea lion',
#   'id': 49,
#   'info': 'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.\n'
#           '\n'
#           'Etiam vel augue. Vestibulum rutrum rutrum neque. Aenean auctor '
#           'gravida sem.',
#   'location': 'China',
#   'scientific_name': 'Eumetopias jubatus'},
#  {'common_name': 'Tawny eagle',
#   'id': 50,
#   'info': 'Quisque id justo sit amet sapien dignissim vestibulum. Vestibulum '
#           'ante ipsum primis in faucibus orci luctus et ultrices posuere '
#           'cubilia Curae; Nulla dapibus dolor vel est. Donec odio justo, '
#           'sollicitudin ut, suscipit a, feugiat et, eros.',
#   'location': 'China',
#   'scientific_name': 'Anitibyx armatus'},
#  {'common_name': 'Pronghorn',
#   'id': 51,
#   'info': 'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.',
#   'location': 'Russia',
#   'scientific_name': 'Antilocapra americana'},
#  {'common_name': 'White-throated monitor',
#   'id': 52,
#   'info': 'Sed ante. Vivamus tortor. Duis mattis egestas metus.',
#   'location': 'China',
#   'scientific_name': 'Varanus albigularis'},
#  {'common_name': 'Turkey vulture',
#   'id': 53,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.\n'
#           '\n'
#           'Vestibulum quam sapien, varius ut, blandit non, interdum in, ante. '
#           'Vestibulum ante ipsum primis in faucibus orci luctus et ultrices '
#           'posuere cubilia Curae; Duis faucibus accumsan odio. Curabitur '
#           'convallis.',
#   'location': 'Malta',
#   'scientific_name': 'Cathartes aura'},
#  {'common_name': 'Bulbul, black-eyed',
#   'id': 54,
#   'info': 'Phasellus in felis. Donec semper sapien a libero. Nam dui.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Pycnonotus barbatus'},
#  {'common_name': 'South African hedgehog',
#   'id': 55,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.\n'
#           '\n'
#           'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.',
#   'location': 'Russia',
#   'scientific_name': 'Erinaceus frontalis'},
#  {'common_name': 'Duck, white-faced whistling',
#   'id': 56,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.',
#   'location': 'China',
#   'scientific_name': 'Dendrocygna viduata'},
#  {'common_name': 'Rufous tree pie',
#   'id': 57,
#   'info': 'Vestibulum ac est lacinia nisi venenatis tristique. Fusce congue, '
#           'diam id ornare imperdiet, sapien urna pretium nisl, ut volutpat '
#           'sapien arcu sed augue. Aliquam erat volutpat.\n'
#           '\n'
#           'In congue. Etiam justo. Etiam pretium iaculis justo.',
#   'location': 'Japan',
#   'scientific_name': 'Dendrocitta vagabunda'},
#  {'common_name': 'White spoonbill',
#   'id': 58,
#   'info': 'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.\n'
#           '\n'
#           'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'Luxembourg',
#   'scientific_name': 'Platalea leucordia'},
#  {'common_name': 'Comb duck',
#   'id': 59,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.\n'
#           '\n'
#           'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.',
#   'location': 'Brazil',
#   'scientific_name': 'Sarkidornis melanotos'},
#  {'common_name': 'Anteater, giant',
#   'id': 60,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.\n'
#           '\n'
#           'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.',
#   'location': 'Peru',
#   'scientific_name': 'Myrmecophaga tridactyla'},
#  {'common_name': 'Steenbuck',
#   'id': 61,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.\n'
#           '\n'
#           'Vestibulum quam sapien, varius ut, blandit non, interdum in, ante. '
#           'Vestibulum ante ipsum primis in faucibus orci luctus et ultrices '
#           'posuere cubilia Curae; Duis faucibus accumsan odio. Curabitur '
#           'convallis.',
#   'location': 'Indonesia',
#   'scientific_name': 'Raphicerus campestris'},
#  {'common_name': 'Elk, Wapiti',
#   'id': 62,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.\n'
#           '\n'
#           'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.',
#   'location': 'Russia',
#   'scientific_name': 'Cervus canadensis'},
#  {'common_name': 'Boubou, southern',
#   'id': 63,
#   'info': 'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.\n'
#           '\n'
#           'Curabitur gravida nisi at nibh. In hac habitasse platea dictumst. '
#           'Aliquam augue quam, sollicitudin vitae, consectetuer eget, rutrum '
#           'at, lorem.',
#   'location': 'China',
#   'scientific_name': 'Laniarius ferrugineus'},
#  {'common_name': "Cat, miner's",
#   'id': 64,
#   'info': 'Duis consequat dui nec nisi volutpat eleifend. Donec ut dolor. '
#           'Morbi vel lectus in quam fringilla rhoncus.',
#   'location': 'Venezuela',
#   'scientific_name': 'Bassariscus astutus'},
#  {'common_name': 'Indian mynah',
#   'id': 65,
#   'info': 'In hac habitasse platea dictumst. Morbi vestibulum, velit id '
#           'pretium iaculis, diam erat fermentum justo, nec condimentum neque '
#           'sapien placerat ante. Nulla justo.',
#   'location': 'South Africa',
#   'scientific_name': 'Acridotheres tristis'},
#  {'common_name': 'Bushpig',
#   'id': 66,
#   'info': 'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.',
#   'location': 'Sweden',
#   'scientific_name': 'Potamochoerus porcus'},
#  {'common_name': 'Fowl, helmeted guinea',
#   'id': 67,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'France',
#   'scientific_name': 'Numida meleagris'},
#  {'common_name': 'Lemur, grey mouse',
#   'id': 68,
#   'info': 'Vestibulum quam sapien, varius ut, blandit non, interdum in, ante. '
#           'Vestibulum ante ipsum primis in faucibus orci luctus et ultrices '
#           'posuere cubilia Curae; Duis faucibus accumsan odio. Curabitur '
#           'convallis.\n'
#           '\n'
#           'Duis consequat dui nec nisi volutpat eleifend. Donec ut dolor. '
#           'Morbi vel lectus in quam fringilla rhoncus.',
#   'location': 'China',
#   'scientific_name': 'Microcebus murinus'},
#  {'common_name': 'Tayra',
#   'id': 69,
#   'info': 'In sagittis dui vel nisl. Duis ac nibh. Fusce lacus purus, aliquet '
#           'at, feugiat non, pretium quis, lectus.\n'
#           '\n'
#           'Suspendisse potenti. In eleifend quam a odio. In hac habitasse '
#           'platea dictumst.',
#   'location': 'Indonesia',
#   'scientific_name': 'Eira barbata'},
#  {'common_name': 'Crab, red lava',
#   'id': 70,
#   'info': 'In quis justo. Maecenas rhoncus aliquam lacus. Morbi quis tortor id '
#           'nulla ultrices aliquet.\n'
#           '\n'
#           'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.',
#   'location': 'Indonesia',
#   'scientific_name': 'Graspus graspus'},
#  {'common_name': 'Baboon, savanna',
#   'id': 71,
#   'info': 'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.',
#   'location': 'Indonesia',
#   'scientific_name': 'Papio cynocephalus'},
#  {'common_name': 'Red-capped cardinal',
#   'id': 72,
#   'info': 'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.\n'
#           '\n'
#           'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.',
#   'location': 'Pakistan',
#   'scientific_name': 'Paroaria gularis'},
#  {'common_name': 'Weaver, chestnut',
#   'id': 73,
#   'info': 'Curabitur gravida nisi at nibh. In hac habitasse platea dictumst. '
#           'Aliquam augue quam, sollicitudin vitae, consectetuer eget, rutrum '
#           'at, lorem.\n'
#           '\n'
#           'Integer tincidunt ante vel ipsum. Praesent blandit lacinia erat. '
#           'Vestibulum sed magna at nunc commodo placerat.',
#   'location': 'Brazil',
#   'scientific_name': 'Ploceus rubiginosus'},
#  {'common_name': 'Fox, north american red',
#   'id': 74,
#   'info': 'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.\n'
#           '\n'
#           'Proin interdum mauris non ligula pellentesque ultrices. Phasellus '
#           'id sapien in sapien iaculis congue. Vivamus metus arcu, adipiscing '
#           'molestie, hendrerit at, vulputate vitae, nisl.',
#   'location': 'China',
#   'scientific_name': 'Vulpes vulpes'},
#  {'common_name': 'Malabar squirrel',
#   'id': 75,
#   'info': 'Fusce posuere felis sed lacus. Morbi sem mauris, laoreet ut, '
#           'rhoncus aliquet, pulvinar sed, nisl. Nunc rhoncus dui vel sem.\n'
#           '\n'
#           'Sed sagittis. Nam congue, risus semper porta volutpat, quam pede '
#           'lobortis ligula, sit amet eleifend pede libero quis orci. Nullam '
#           'molestie nibh in lectus.',
#   'location': 'Argentina',
#   'scientific_name': 'Ratufa indica'},
#  {'common_name': "Swainson's francolin",
#   'id': 76,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.',
#   'location': 'Sweden',
#   'scientific_name': 'Francolinus swainsonii'},
#  {'common_name': 'Crab, sally lightfoot',
#   'id': 77,
#   'info': 'In congue. Etiam justo. Etiam pretium iaculis justo.\n'
#           '\n'
#           'In hac habitasse platea dictumst. Etiam faucibus cursus urna. Ut '
#           'tellus.',
#   'location': 'China',
#   'scientific_name': 'Graspus graspus'},
#  {'common_name': 'Common raccoon',
#   'id': 78,
#   'info': 'Fusce consequat. Nulla nisl. Nunc nisl.',
#   'location': 'Costa Rica',
#   'scientific_name': 'Procyon lotor'},
#  {'common_name': 'Phalarope, grey',
#   'id': 79,
#   'info': 'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.\n'
#           '\n'
#           'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.',
#   'location': 'Bolivia',
#   'scientific_name': 'Phalaropus fulicarius'},
#  {'common_name': 'Lizard, goanna',
#   'id': 80,
#   'info': 'Integer tincidunt ante vel ipsum. Praesent blandit lacinia erat. '
#           'Vestibulum sed magna at nunc commodo placerat.',
#   'location': 'Poland',
#   'scientific_name': 'Varanus sp.'},
#  {'common_name': 'Cereopsis goose',
#   'id': 81,
#   'info': 'Aliquam quis turpis eget elit sodales scelerisque. Mauris sit amet '
#           'eros. Suspendisse accumsan tortor quis turpis.',
#   'location': 'Indonesia',
#   'scientific_name': 'Cereopsis novaehollandiae'},
#  {'common_name': 'Bee-eater, nubian',
#   'id': 82,
#   'info': 'Duis aliquam convallis nunc. Proin at turpis a pede posuere '
#           'nonummy. Integer non velit.\n'
#           '\n'
#           'Donec diam neque, vestibulum eget, vulputate ut, ultrices vel, '
#           'augue. Vestibulum ante ipsum primis in faucibus orci luctus et '
#           'ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum '
#           'aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis '
#           'sapien sapien non mi. Integer ac neque.',
#   'location': 'China',
#   'scientific_name': 'Merops nubicus'},
#  {'common_name': 'Phalarope, northern',
#   'id': 83,
#   'info': 'Duis bibendum. Morbi non quam nec dui luctus rutrum. Nulla tellus.\n'
#           '\n'
#           'In sagittis dui vel nisl. Duis ac nibh. Fusce lacus purus, aliquet '
#           'at, feugiat non, pretium quis, lectus.',
#   'location': 'Poland',
#   'scientific_name': 'Phalaropus lobatus'},
#  {'common_name': 'Coot, red-knobbed',
#   'id': 84,
#   'info': 'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.',
#   'location': 'Indonesia',
#   'scientific_name': 'Fulica cristata'},
#  {'common_name': 'Worm snake (unidentified)',
#   'id': 85,
#   'info': 'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
#           'ipsum. Integer a nibh.\n'
#           '\n'
#           'In quis justo. Maecenas rhoncus aliquam lacus. Morbi quis tortor id '
#           'nulla ultrices aliquet.',
#   'location': 'China',
#   'scientific_name': 'Carphophis sp.'},
#  {'common_name': 'Eastern cottontail rabbit',
#   'id': 86,
#   'info': 'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.\n'
#           '\n'
#           'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.',
#   'location': 'China',
#   'scientific_name': 'Sylvilagus floridanus'},
#  {'common_name': 'Fox, north american red',
#   'id': 87,
#   'info': 'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'Greece',
#   'scientific_name': 'Vulpes vulpes'},
#  {'common_name': 'Bleeding heart monkey',
#   'id': 88,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.\n'
#           '\n'
#           'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.',
#   'location': 'Ukraine',
#   'scientific_name': 'Theropithecus gelada'},
#  {'common_name': 'Lizard (unidentified)',
#   'id': 89,
#   'info': 'Aliquam quis turpis eget elit sodales scelerisque. Mauris sit amet '
#           'eros. Suspendisse accumsan tortor quis turpis.\n'
#           '\n'
#           'Sed ante. Vivamus tortor. Duis mattis egestas metus.',
#   'location': 'Indonesia',
#   'scientific_name': 'unavailable'},
#  {'common_name': 'Cape wild cat',
#   'id': 90,
#   'info': 'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.\n'
#           '\n'
#           'Morbi non lectus. Aliquam sit amet diam in magna bibendum '
#           'imperdiet. Nullam orci pede, venenatis non, sodales sed, tincidunt '
#           'eu, felis.',
#   'location': 'Portugal',
#   'scientific_name': 'Felis libyca'},
#  {'common_name': 'Bulbul, black-fronted',
#   'id': 91,
#   'info': 'Duis bibendum. Morbi non quam nec dui luctus rutrum. Nulla tellus.\n'
#           '\n'
#           'In sagittis dui vel nisl. Duis ac nibh. Fusce lacus purus, aliquet '
#           'at, feugiat non, pretium quis, lectus.',
#   'location': 'Indonesia',
#   'scientific_name': 'Pycnonotus nigricans'},
#  {'common_name': 'Sloth, two-toed tree',
#   'id': 92,
#   'info': 'In congue. Etiam justo. Etiam pretium iaculis justo.\n'
#           '\n'
#           'In hac habitasse platea dictumst. Etiam faucibus cursus urna. Ut '
#           'tellus.',
#   'location': 'Poland',
#   'scientific_name': 'Choloepus hoffmani'},
#  {'common_name': 'Bunting, crested',
#   'id': 93,
#   'info': 'Duis bibendum. Morbi non quam nec dui luctus rutrum. Nulla tellus.',
#   'location': 'Poland',
#   'scientific_name': 'Melophus lathami'},
#  {'common_name': 'Gnu, brindled',
#   'id': 94,
#   'info': 'Sed sagittis. Nam congue, risus semper porta volutpat, quam pede '
#           'lobortis ligula, sit amet eleifend pede libero quis orci. Nullam '
#           'molestie nibh in lectus.\n'
#           '\n'
#           'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'Ireland',
#   'scientific_name': 'Connochaetus taurinus'},
#  {'common_name': 'Capuchin, black-capped',
#   'id': 95,
#   'info': 'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.',
#   'location': 'Russia',
#   'scientific_name': 'Cebus apella'},
#  {'common_name': 'Bee-eater, nubian',
#   'id': 96,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'Indonesia',
#   'scientific_name': 'Merops nubicus'},
#  {'common_name': 'Lemming, collared',
#   'id': 97,
#   'info': 'Maecenas tristique, est et tempus semper, est quam pharetra magna, '
#           'ac consequat metus sapien ut nunc. Vestibulum ante ipsum primis in '
#           'faucibus orci luctus et ultrices posuere cubilia Curae; Mauris '
#           'viverra diam vitae quam. Suspendisse potenti.',
#   'location': 'Philippines',
#   'scientific_name': 'Dicrostonyx groenlandicus'},
#  {'common_name': 'Gorilla, western lowland',
#   'id': 98,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.',
#   'location': 'China',
#   'scientific_name': 'Gorilla gorilla'},
#  {'common_name': 'Possum, golden brush-tailed',
#   'id': 99,
#   'info': 'Donec diam neque, vestibulum eget, vulputate ut, ultrices vel, '
#           'augue. Vestibulum ante ipsum primis in faucibus orci luctus et '
#           'ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum '
#           'aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis '
#           'sapien sapien non mi. Integer ac neque.',
#   'location': 'Myanmar',
#   'scientific_name': 'Trichosurus vulpecula'},
#  {'common_name': 'Black rhinoceros',
#   'id': 100,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.',
#   'location': 'Chile',
#   'scientific_name': 'Diceros bicornis'},
#  {'common_name': 'Mongoose, javan gold-spotted',
#   'id': 101,
#   'info': 'Duis aliquam convallis nunc. Proin at turpis a pede posuere '
#           'nonummy. Integer non velit.',
#   'location': 'France',
#   'scientific_name': 'Herpestes javanicus'},
#  {'common_name': 'Black spider monkey',
#   'id': 102,
#   'info': 'Sed sagittis. Nam congue, risus semper porta volutpat, quam pede '
#           'lobortis ligula, sit amet eleifend pede libero quis orci. Nullam '
#           'molestie nibh in lectus.\n'
#           '\n'
#           'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.',
#   'location': 'Portugal',
#   'scientific_name': 'Ateles paniscus'},
#  {'common_name': 'Dove, ring',
#   'id': 103,
#   'info': 'Etiam vel augue. Vestibulum rutrum rutrum neque. Aenean auctor '
#           'gravida sem.\n'
#           '\n'
#           'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.',
#   'location': 'Colombia',
#   'scientific_name': 'Columba palumbus'},
#  {'common_name': 'Blackbird, red-winged',
#   'id': 104,
#   'info': 'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.\n'
#           '\n'
#           'Fusce consequat. Nulla nisl. Nunc nisl.',
#   'location': 'Argentina',
#   'scientific_name': 'Agelaius phoeniceus'},
#  {'common_name': 'Macaw, green-winged',
#   'id': 105,
#   'info': 'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.',
#   'location': 'Poland',
#   'scientific_name': 'Ara chloroptera'},
#  {'common_name': 'Frilled dragon',
#   'id': 106,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.',
#   'location': 'China',
#   'scientific_name': 'Chlamydosaurus kingii'},
#  {'common_name': 'Gull, southern black-backed',
#   'id': 107,
#   'info': 'Duis consequat dui nec nisi volutpat eleifend. Donec ut dolor. '
#           'Morbi vel lectus in quam fringilla rhoncus.\n'
#           '\n'
#           'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.',
#   'location': 'Philippines',
#   'scientific_name': 'Larus dominicanus'},
#  {'common_name': 'Kangaroo, eastern grey',
#   'id': 108,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.\n'
#           '\n'
#           'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.',
#   'location': 'Finland',
#   'scientific_name': 'Macropus giganteus'},
#  {'common_name': 'Red-headed woodpecker',
#   'id': 109,
#   'info': 'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.\n'
#           '\n'
#           'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'China',
#   'scientific_name': 'Melanerpes erythrocephalus'},
#  {'common_name': 'Indian tree pie',
#   'id': 110,
#   'info': 'In sagittis dui vel nisl. Duis ac nibh. Fusce lacus purus, aliquet '
#           'at, feugiat non, pretium quis, lectus.',
#   'location': 'China',
#   'scientific_name': 'Dendrocitta vagabunda'},
#  {'common_name': 'Starling, red-shouldered glossy',
#   'id': 111,
#   'info': 'Cras non velit nec nisi vulputate nonummy. Maecenas tincidunt lacus '
#           'at velit. Vivamus vel nulla eget eros elementum pellentesque.',
#   'location': 'Nigeria',
#   'scientific_name': 'Lamprotornis nitens'},
#  {'common_name': 'Cape white-eye',
#   'id': 112,
#   'info': 'In quis justo. Maecenas rhoncus aliquam lacus. Morbi quis tortor id '
#           'nulla ultrices aliquet.',
#   'location': 'Russia',
#   'scientific_name': 'Zosterops pallidus'},
#  {'common_name': 'Blacksmith plover',
#   'id': 113,
#   'info': 'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.',
#   'location': 'United Arab Emirates',
#   'scientific_name': 'Vanellus armatus'},
#  {'common_name': 'Golden brush-tailed possum',
#   'id': 114,
#   'info': 'Donec diam neque, vestibulum eget, vulputate ut, ultrices vel, '
#           'augue. Vestibulum ante ipsum primis in faucibus orci luctus et '
#           'ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum '
#           'aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis '
#           'sapien sapien non mi. Integer ac neque.',
#   'location': 'Guatemala',
#   'scientific_name': 'Trichosurus vulpecula'},
#  {'common_name': 'Pronghorn',
#   'id': 115,
#   'info': 'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.\n'
#           '\n'
#           'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.',
#   'location': 'Samoa',
#   'scientific_name': 'Antilocapra americana'},
#  {'common_name': 'Cormorant, flightless',
#   'id': 116,
#   'info': 'Donec diam neque, vestibulum eget, vulputate ut, ultrices vel, '
#           'augue. Vestibulum ante ipsum primis in faucibus orci luctus et '
#           'ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum '
#           'aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis '
#           'sapien sapien non mi. Integer ac neque.\n'
#           '\n'
#           'Duis bibendum. Morbi non quam nec dui luctus rutrum. Nulla tellus.',
#   'location': 'Japan',
#   'scientific_name': 'Nannopterum harrisi'},
#  {'common_name': 'Heron, green',
#   'id': 117,
#   'info': 'Duis bibendum, felis sed interdum venenatis, turpis enim blandit '
#           'mi, in porttitor pede justo eu massa. Donec dapibus. Duis at velit '
#           'eu est congue elementum.',
#   'location': 'Morocco',
#   'scientific_name': 'Butorides striatus'},
#  {'common_name': 'Wallaby, red-necked',
#   'id': 118,
#   'info': 'In hac habitasse platea dictumst. Morbi vestibulum, velit id '
#           'pretium iaculis, diam erat fermentum justo, nec condimentum neque '
#           'sapien placerat ante. Nulla justo.',
#   'location': 'United States',
#   'scientific_name': 'Macropus rufogriseus'},
#  {'common_name': 'Heron, green',
#   'id': 119,
#   'info': 'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'Philippines',
#   'scientific_name': 'Butorides striatus'},
#  {'common_name': 'Great white pelican',
#   'id': 120,
#   'info': 'Sed ante. Vivamus tortor. Duis mattis egestas metus.\n'
#           '\n'
#           'Aenean fermentum. Donec ut mauris eget massa tempor convallis. '
#           'Nulla neque libero, convallis eget, eleifend luctus, ultricies eu, '
#           'nibh.',
#   'location': 'Democratic Republic of the Congo',
#   'scientific_name': 'Pelecans onocratalus'},
#  {'common_name': 'Prairie falcon',
#   'id': 121,
#   'info': 'In hac habitasse platea dictumst. Etiam faucibus cursus urna. Ut '
#           'tellus.',
#   'location': 'France',
#   'scientific_name': 'Falco mexicanus'},
#  {'common_name': 'Toucan, red-billed',
#   'id': 122,
#   'info': 'Pellentesque at nulla. Suspendisse potenti. Cras in purus eu magna '
#           'vulputate luctus.\n'
#           '\n'
#           'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.',
#   'location': 'United States',
#   'scientific_name': 'Ramphastos tucanus'},
#  {'common_name': 'Godwit, hudsonian',
#   'id': 123,
#   'info': 'Sed ante. Vivamus tortor. Duis mattis egestas metus.',
#   'location': 'Russia',
#   'scientific_name': 'Limosa haemastica'},
#  {'common_name': 'Duiker, gray',
#   'id': 124,
#   'info': 'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.',
#   'location': 'Portugal',
#   'scientific_name': 'Sylvicapra grimma'},
#  {'common_name': "Grant's gazelle",
#   'id': 125,
#   'info': 'Integer tincidunt ante vel ipsum. Praesent blandit lacinia erat. '
#           'Vestibulum sed magna at nunc commodo placerat.\n'
#           '\n'
#           'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.',
#   'location': 'United States',
#   'scientific_name': 'Gazella granti'},
#  {'common_name': 'Painted stork',
#   'id': 126,
#   'info': 'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Mycteria leucocephala'},
#  {'common_name': 'Langur, common',
#   'id': 127,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.\n'
#           '\n'
#           'Vestibulum quam sapien, varius ut, blandit non, interdum in, ante. '
#           'Vestibulum ante ipsum primis in faucibus orci luctus et ultrices '
#           'posuere cubilia Curae; Duis faucibus accumsan odio. Curabitur '
#           'convallis.',
#   'location': 'Costa Rica',
#   'scientific_name': 'Semnopithecus entellus'},
#  {'common_name': 'Striped dolphin',
#   'id': 128,
#   'info': 'Curabitur in libero ut massa volutpat convallis. Morbi odio odio, '
#           'elementum eu, interdum eu, tincidunt in, leo. Maecenas pulvinar '
#           'lobortis est.\n'
#           '\n'
#           'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.',
#   'location': 'Ireland',
#   'scientific_name': 'Stenella coeruleoalba'},
#  {'common_name': 'Duck, mountain',
#   'id': 129,
#   'info': 'Duis consequat dui nec nisi volutpat eleifend. Donec ut dolor. '
#           'Morbi vel lectus in quam fringilla rhoncus.',
#   'location': 'Russia',
#   'scientific_name': 'Hymenolaimus malacorhynchus'},
#  {'common_name': 'Striated heron',
#   'id': 130,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.\n'
#           '\n'
#           'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
#           'ipsum. Integer a nibh.',
#   'location': 'Portugal',
#   'scientific_name': 'Butorides striatus'},
#  {'common_name': 'Native cat',
#   'id': 131,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.\n'
#           '\n'
#           'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
# ...
#   'id': 959,
#   'info': 'Proin interdum mauris non ligula pellentesque ultrices. Phasellus '
#           'id sapien in sapien iaculis congue. Vivamus metus arcu, adipiscing '
#           'molestie, hendrerit at, vulputate vitae, nisl.',
#   'location': 'Tajikistan',
#   'scientific_name': 'Psophia viridis'},
#  {'common_name': 'Australian pelican',
#   'id': 960,
#   'info': 'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.',
#   'location': 'Indonesia',
#   'scientific_name': 'Pelecanus conspicillatus'},
#  {'common_name': 'Antelope, roan',
#   'id': 961,
#   'info': 'Aliquam quis turpis eget elit sodales scelerisque. Mauris sit amet '
#           'eros. Suspendisse accumsan tortor quis turpis.\n'
#           '\n'
#           'Sed ante. Vivamus tortor. Duis mattis egestas metus.',
#   'location': 'Sweden',
#   'scientific_name': 'Hippotragus equinus'},
#  {'common_name': 'Bonnet macaque',
#   'id': 962,
#   'info': 'In hac habitasse platea dictumst. Etiam faucibus cursus urna. Ut '
#           'tellus.\n'
#           '\n'
#           'Nulla ut erat id mauris vulputate elementum. Nullam varius. Nulla '
#           'facilisi.',
#   'location': 'Indonesia',
#   'scientific_name': 'Macaca radiata'},
#  {'common_name': 'Gray rhea',
#   'id': 963,
#   'info': 'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.\n'
#           '\n'
#           'Morbi non lectus. Aliquam sit amet diam in magna bibendum '
#           'imperdiet. Nullam orci pede, venenatis non, sodales sed, tincidunt '
#           'eu, felis.',
#   'location': 'Japan',
#   'scientific_name': 'Rhea americana'},
#  {'common_name': 'Jungle cat',
#   'id': 964,
#   'info': 'Duis consequat dui nec nisi volutpat eleifend. Donec ut dolor. '
#           'Morbi vel lectus in quam fringilla rhoncus.',
#   'location': 'Poland',
#   'scientific_name': 'Felis chaus'},
#  {'common_name': 'Cormorant, javanese',
#   'id': 965,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.\n'
#           '\n'
#           'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
#           'ipsum. Integer a nibh.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Phalacrocorax niger'},
#  {'common_name': 'Black bear',
#   'id': 966,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.\n'
#           '\n'
#           'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
#           'ipsum. Integer a nibh.',
#   'location': 'Canada',
#   'scientific_name': 'Ursus americanus'},
#  {'common_name': 'Pronghorn',
#   'id': 967,
#   'info': 'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.\n'
#           '\n'
#           'Fusce consequat. Nulla nisl. Nunc nisl.',
#   'location': 'China',
#   'scientific_name': 'Antilocapra americana'},
#  {'common_name': 'Flamingo, chilean',
#   'id': 968,
#   'info': 'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.\n'
#           '\n'
#           'Etiam vel augue. Vestibulum rutrum rutrum neque. Aenean auctor '
#           'gravida sem.',
#   'location': 'Kazakhstan',
#   'scientific_name': 'Phoenicopterus chilensis'},
#  {'common_name': 'Blue catfish',
#   'id': 969,
#   'info': 'Cras non velit nec nisi vulputate nonummy. Maecenas tincidunt lacus '
#           'at velit. Vivamus vel nulla eget eros elementum pellentesque.',
#   'location': 'Portugal',
#   'scientific_name': 'Ictalurus furcatus'},
#  {'common_name': 'Indian jackal',
#   'id': 970,
#   'info': 'Proin interdum mauris non ligula pellentesque ultrices. Phasellus '
#           'id sapien in sapien iaculis congue. Vivamus metus arcu, adipiscing '
#           'molestie, hendrerit at, vulputate vitae, nisl.\n'
#           '\n'
#           'Aenean lectus. Pellentesque eget nunc. Donec quis orci eget orci '
#           'vehicula condimentum.',
#   'location': 'Indonesia',
#   'scientific_name': 'Canis aureus'},
#  {'common_name': 'Godwit, hudsonian',
#   'id': 971,
#   'info': 'Quisque porta volutpat erat. Quisque erat eros, viverra eget, '
#           'congue eget, semper rutrum, nulla. Nunc purus.',
#   'location': 'Indonesia',
#   'scientific_name': 'Limosa haemastica'},
#  {'common_name': 'Gnu, brindled',
#   'id': 972,
#   'info': 'Quisque id justo sit amet sapien dignissim vestibulum. Vestibulum '
#           'ante ipsum primis in faucibus orci luctus et ultrices posuere '
#           'cubilia Curae; Nulla dapibus dolor vel est. Donec odio justo, '
#           'sollicitudin ut, suscipit a, feugiat et, eros.',
#   'location': 'Uganda',
#   'scientific_name': 'Connochaetus taurinus'},
#  {'common_name': 'Asian red fox',
#   'id': 973,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.\n'
#           '\n'
#           'Nullam sit amet turpis elementum ligula vehicula consequat. Morbi a '
#           'ipsum. Integer a nibh.',
#   'location': 'China',
#   'scientific_name': 'Vulpes vulpes'},
#  {'common_name': 'Oystercatcher, blackish',
#   'id': 974,
#   'info': 'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.',
#   'location': 'China',
#   'scientific_name': 'Haematopus ater'},
#  {'common_name': 'Carmine bee-eater',
#   'id': 975,
#   'info': 'Integer tincidunt ante vel ipsum. Praesent blandit lacinia erat. '
#           'Vestibulum sed magna at nunc commodo placerat.\n'
#           '\n'
#           'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.',
#   'location': 'Micronesia',
#   'scientific_name': 'Merops nubicus'},
#  {'common_name': 'Blue wildebeest',
#   'id': 976,
#   'info': 'Duis aliquam convallis nunc. Proin at turpis a pede posuere '
#           'nonummy. Integer non velit.\n'
#           '\n'
#           'Donec diam neque, vestibulum eget, vulputate ut, ultrices vel, '
#           'augue. Vestibulum ante ipsum primis in faucibus orci luctus et '
#           'ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum '
#           'aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis '
#           'sapien sapien non mi. Integer ac neque.',
#   'location': 'China',
#   'scientific_name': 'Connochaetus taurinus'},
#  {'common_name': 'Weaver, red-billed buffalo',
#   'id': 977,
#   'info': 'Praesent blandit. Nam nulla. Integer pede justo, lacinia eget, '
#           'tincidunt eget, tempus vel, pede.\n'
#           '\n'
#           'Morbi porttitor lorem id ligula. Suspendisse ornare consequat '
#           'lectus. In est risus, auctor sed, tristique in, tempus sit amet, '
#           'sem.',
#   'location': 'China',
#   'scientific_name': 'Bubalornis niger'},
#  {'common_name': 'Cheetah',
#   'id': 978,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.',
#   'location': 'China',
#   'scientific_name': 'Acinynox jubatus'},
#  {'common_name': 'Yellow-crowned night heron',
#   'id': 979,
#   'info': 'Proin eu mi. Nulla ac enim. In tempor, turpis nec euismod '
#           'scelerisque, quam turpis adipiscing lorem, vitae mattis nibh ligula '
#           'nec sem.',
#   'location': 'China',
#   'scientific_name': 'Nyctanassa violacea'},
#  {'common_name': 'Owl, white-browed',
#   'id': 980,
#   'info': 'Duis bibendum, felis sed interdum venenatis, turpis enim blandit '
#           'mi, in porttitor pede justo eu massa. Donec dapibus. Duis at velit '
#           'eu est congue elementum.\n'
#           '\n'
#           'In hac habitasse platea dictumst. Morbi vestibulum, velit id '
#           'pretium iaculis, diam erat fermentum justo, nec condimentum neque '
#           'sapien placerat ante. Nulla justo.',
#   'location': 'Indonesia',
#   'scientific_name': 'Ninox superciliaris'},
#  {'common_name': "Miner's cat",
#   'id': 981,
#   'info': 'Phasellus in felis. Donec semper sapien a libero. Nam dui.',
#   'location': 'Bolivia',
#   'scientific_name': 'Bassariscus astutus'},
#  {'common_name': 'Lizard (unidentified)',
#   'id': 982,
#   'info': 'Proin interdum mauris non ligula pellentesque ultrices. Phasellus '
#           'id sapien in sapien iaculis congue. Vivamus metus arcu, adipiscing '
#           'molestie, hendrerit at, vulputate vitae, nisl.',
#   'location': 'Indonesia',
#   'scientific_name': 'unavailable'},
#  {'common_name': 'Turaco, violet-crested',
#   'id': 983,
#   'info': 'Donec diam neque, vestibulum eget, vulputate ut, ultrices vel, '
#           'augue. Vestibulum ante ipsum primis in faucibus orci luctus et '
#           'ultrices posuere cubilia Curae; Donec pharetra, magna vestibulum '
#           'aliquet ultrices, erat tortor sollicitudin mi, sit amet lobortis '
#           'sapien sapien non mi. Integer ac neque.',
#   'location': 'Argentina',
#   'scientific_name': 'Tauraco porphyrelophus'},
#  {'common_name': 'Sparrow, rufous-collared',
#   'id': 984,
#   'info': 'Fusce posuere felis sed lacus. Morbi sem mauris, laoreet ut, '
#           'rhoncus aliquet, pulvinar sed, nisl. Nunc rhoncus dui vel sem.',
#   'location': 'China',
#   'scientific_name': 'Zonotrichia capensis'},
#  {'common_name': 'Pale-throated three-toed sloth',
#   'id': 985,
#   'info': 'Nullam porttitor lacus at turpis. Donec posuere metus vitae ipsum. '
#           'Aliquam non mauris.',
#   'location': 'Iran',
#   'scientific_name': 'Bradypus tridactylus'},
#  {'common_name': 'White-necked raven',
#   'id': 986,
#   'info': 'Cum sociis natoque penatibus et magnis dis parturient montes, '
#           'nascetur ridiculus mus. Vivamus vestibulum sagittis sapien. Cum '
#           'sociis natoque penatibus et magnis dis parturient montes, nascetur '
#           'ridiculus mus.',
#   'location': 'Ukraine',
#   'scientific_name': 'Corvus albicollis'},
#  {'common_name': 'Black-capped chickadee',
#   'id': 987,
#   'info': 'Sed ante. Vivamus tortor. Duis mattis egestas metus.\n'
#           '\n'
#           'Aenean fermentum. Donec ut mauris eget massa tempor convallis. '
#           'Nulla neque libero, convallis eget, eleifend luctus, ultricies eu, '
#           'nibh.',
#   'location': 'Poland',
#   'scientific_name': 'Parus atricapillus'},
#  {'common_name': 'Yellow mongoose',
#   'id': 988,
#   'info': 'Aenean fermentum. Donec ut mauris eget massa tempor convallis. '
#           'Nulla neque libero, convallis eget, eleifend luctus, ultricies eu, '
#           'nibh.\n'
#           '\n'
#           'Quisque id justo sit amet sapien dignissim vestibulum. Vestibulum '
#           'ante ipsum primis in faucibus orci luctus et ultrices posuere '
#           'cubilia Curae; Nulla dapibus dolor vel est. Donec odio justo, '
#           'sollicitudin ut, suscipit a, feugiat et, eros.',
#   'location': 'Ireland',
#   'scientific_name': 'Cynictis penicillata'},
#  {'common_name': 'Greater blue-eared starling',
#   'id': 989,
#   'info': 'Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Proin '
#           'risus. Praesent lectus.\n'
#           '\n'
#           'Vestibulum quam sapien, varius ut, blandit non, interdum in, ante. '
#           'Vestibulum ante ipsum primis in faucibus orci luctus et ultrices '
#           'posuere cubilia Curae; Duis faucibus accumsan odio. Curabitur '
#           'convallis.',
#   'location': 'Indonesia',
#   'scientific_name': 'Lamprotornis chalybaeus'},
#  {'common_name': 'Kangaroo, jungle',
#   'id': 990,
#   'info': 'Nam ultrices, libero non mattis pulvinar, nulla pede ullamcorper '
#           'augue, a suscipit nulla elit ac nulla. Sed vel enim sit amet nunc '
#           'viverra dapibus. Nulla suscipit ligula in lacus.\n'
#           '\n'
#           'Curabitur at ipsum ac tellus semper interdum. Mauris ullamcorper '
#           'purus sit amet nulla. Quisque arcu libero, rutrum ac, lobortis vel, '
#           'dapibus at, diam.',
#   'location': 'Sweden',
#   'scientific_name': 'Macropus agilis'},
#  {'common_name': 'White-necked stork',
#   'id': 991,
#   'info': 'Morbi non lectus. Aliquam sit amet diam in magna bibendum '
#           'imperdiet. Nullam orci pede, venenatis non, sodales sed, tincidunt '
#           'eu, felis.\n'
#           '\n'
#           'Fusce posuere felis sed lacus. Morbi sem mauris, laoreet ut, '
#           'rhoncus aliquet, pulvinar sed, nisl. Nunc rhoncus dui vel sem.',
#   'location': 'Oman',
#   'scientific_name': 'Ciconia episcopus'},
#  {'common_name': 'Pacific gull',
#   'id': 992,
#   'info': 'Maecenas leo odio, condimentum id, luctus nec, molestie sed, justo. '
#           'Pellentesque viverra pede ac diam. Cras pellentesque volutpat dui.',
#   'location': 'Cameroon',
#   'scientific_name': 'Gabianus pacificus'},
#  {'common_name': 'Gnu, brindled',
#   'id': 993,
#   'info': 'Suspendisse potenti. In eleifend quam a odio. In hac habitasse '
#           'platea dictumst.\n'
#           '\n'
#           'Maecenas ut massa quis augue luctus tincidunt. Nulla mollis '
#           'molestie lorem. Quisque ut erat.',
#   'location': 'China',
#   'scientific_name': 'Connochaetus taurinus'},
#  {'common_name': 'Bettong, brush-tailed',
#   'id': 994,
#   'info': 'Curabitur at ipsum ac tellus semper interdum. Mauris ullamcorper '
#           'purus sit amet nulla. Quisque arcu libero, rutrum ac, lobortis vel, '
#           'dapibus at, diam.',
#   'location': 'Norway',
#   'scientific_name': 'Bettongia penicillata'},
#  {'common_name': 'Screamer, crested',
#   'id': 995,
#   'info': 'Etiam vel augue. Vestibulum rutrum rutrum neque. Aenean auctor '
#           'gravida sem.\n'
#           '\n'
#           'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.',
#   'location': 'Ireland',
#   'scientific_name': 'Chauna torquata'},
#  {'common_name': 'Savannah deer (unidentified)',
#   'id': 996,
#   'info': 'In quis justo. Maecenas rhoncus aliquam lacus. Morbi quis tortor id '
#           'nulla ultrices aliquet.',
#   'location': 'Portugal',
#   'scientific_name': 'unavailable'},
#  {'common_name': 'Goose, canada',
#   'id': 997,
#   'info': 'Praesent id massa id nisl venenatis lacinia. Aenean sit amet justo. '
#           'Morbi ut odio.\n'
#           '\n'
#           'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'Czech Republic',
#   'scientific_name': 'Branta canadensis'},
#  {'common_name': 'White-nosed coatimundi',
#   'id': 998,
#   'info': 'Mauris enim leo, rhoncus sed, vestibulum sit amet, cursus id, '
#           'turpis. Integer aliquet, massa id lobortis convallis, tortor risus '
#           'dapibus augue, vel accumsan tellus nisi eu orci. Mauris lacinia '
#           'sapien quis libero.',
#   'location': 'China',
#   'scientific_name': 'Nasua narica'},
#  {'common_name': 'Rattlesnake, eastern diamondback',
#   'id': 999,
#   'info': 'Cras mi pede, malesuada in, imperdiet et, commodo vulputate, justo. '
#           'In blandit ultrices enim. Lorem ipsum dolor sit amet, consectetuer '
#           'adipiscing elit.',
#   'location': 'Poland',
#   'scientific_name': 'Crotalus adamanteus'},
#  {'common_name': 'Sloth, two-toed tree',
#   'id': 1000,
#   'info': 'Curabitur in libero ut massa volutpat convallis. Morbi odio odio, '
#           'elementum eu, interdum eu, tincidunt in, leo. Maecenas pulvinar '
#           'lobortis est.\n'
#           '\n'
#           'Phasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien '
#           'cursus vestibulum.',
#   'location': 'United States',
#   'scientific_name': 'Choloepus hoffmani'}]

# %%
# Print the first instance
response_json = response.json()
pprint(response_json[0])
# Out:
# {'common_name': 'Tiger cat',
#  'id': 1,
#  'info': 'Curabitur at ipsum ac tellus semper interdum. Mauris ullamcorper '
#          'purus sit amet nulla. Quisque arcu libero, rutrum ac, lobortis vel, '
#          'dapibus at, diam.',
#  'location': 'Russia',
#  'scientific_name': 'Dasyurus maculatus'}

# %%
# Print the last instance
response_json[len(response_json)-1]
# Out:
# {'id': 1000,
#  'common_name': 'Sloth, two-toed tree',
#  'scientific_name': 'Choloepus hoffmani',
#  'info': 'Curabitur in libero ut massa volutpat convallis. Morbi odio odio, elementum eu, interdum eu, tincidunt in, leo. Maecenas pulvinar lobortis est.\n\nPhasellus sit amet erat. Nulla tempus. Vivamus in felis eu sapien cursus vestibulum.',
#  'location': 'United States'}

# %%
# Print the first and last articles
pprint(f"The first video is{response_json[0]}.")
pprint(f"The last video is {response_json[-1]}.")
# Out:
# ("The first video is{'id': 1, 'common_name': 'Tiger cat', 'scientific_name': "
#  "'Dasyurus maculatus', 'info': 'Curabitur at ipsum ac tellus semper interdum. "
#  'Mauris ullamcorper purus sit amet nulla. Quisque arcu libero, rutrum ac, '
#  "lobortis vel, dapibus at, diam.', 'location': 'Russia'}.")
# ("The last video is {'id': 1000, 'common_name': 'Sloth, two-toed tree', "
#  "'scientific_name': 'Choloepus hoffmani', 'info': 'Curabitur in libero ut "
#  'massa volutpat convallis. Morbi odio odio, elementum eu, interdum eu, '
#  'tincidunt in, leo. Maecenas pulvinar lobortis est.\\n\\nPhasellus sit amet '
#  "erat. Nulla tempus. Vivamus in felis eu sapien cursus vestibulum.', "
#  "'location': 'United States'}.")

# %%
# Print the first and last articles
pprint(f"The first video is{response_json[0]}.")
pprint(f"The last video is {response_json[-1]}.")
# Out:
# ("The first video is{'id': 1, 'common_name': 'Tiger cat', 'scientific_name': "
#  "'Dasyurus maculatus', 'info': 'Curabitur at ipsum ac tellus semper interdum. "
#  'Mauris ullamcorper purus sit amet nulla. Quisque arcu libero, rutrum ac, '
#  "lobortis vel, dapibus at, diam.', 'location': 'Russia'}.")
# ("The last video is {'id': 1000, 'common_name': 'Sloth, two-toed tree', "
#  "'scientific_name': 'Choloepus hoffmani', 'info': 'Curabitur in libero ut "
#  'massa volutpat convallis. Morbi odio odio, elementum eu, interdum eu, '
#  'tincidunt in, leo. Maecenas pulvinar lobortis est.\\n\\nPhasellus sit amet '
#  "erat. Nulla tempus. Vivamus in felis eu sapien cursus vestibulum.', "
#  "'location': 'United States'}.")

# %%
#2.5
import json
from pprint import pprint
import requests
#from config import weather_api_key

# %%
#!pip install python-dotenv
import os
from dotenv import load_dotenv
# load the .env environment variables into the notebook
load_dotenv()
#Get the API key from the environment variable as Python variable
weather_api_key = os.getenv("weather_api_key")

# %%
# save configuration info
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "Houston"


# Build partial query URL
query_url = url + "appid=" + weather_api_key + "&q=" + city
query_url = f"{url}appid={weather_api_key}&q={city}&units=imperial"
print(query_url)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-e7fa8e78a98b> in <module>
#       5
#       6 # Build partial query URL
# ----> 7 query_url = url + "appid=" + weather_api_key + "&q=" + city
#       8 query_url = f"{url}appid={weather_api_key}&q={city}&units=imperial"
#       9 print(query_url)
#
# TypeError: must be str, not NoneType

# %%
# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Get the temperature from the response
print(f"The weather API responded with: {weather_json}.")
print("-"*64)
pprint(weather_json)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-fc11c9c39c9a> in <module>
#       1 # Get weather data
# ----> 2 weather_response = requests.get(query_url)
#       3 weather_json = weather_response.json()
#       4
#       5 # Get the temperature from the response
#
# NameError: name 'query_url' is not defined

# %%
#2.4
# Dependencies
import requests
from config import open_weather_api
#save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "Bujumbura"
units = "metric"
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-da3d3b65dcb1> in <module>
#       2 # Dependencies
#       3 import requests
# ----> 4 from config import open_weather_api
#       5 #save config information
#       6 url = "http://api.openweathermap.org/data/2.5/weather?"
#
# ImportError: cannot import name 'open_weather_api'

# %%
import os
from dotenv import load_dotenv
# Load .env environment variables into the notebook
load_dotenv()
#Get the API key from the environment variable and store as Python variable
weather_api_key = os.getenv("weather_api_key")

# %%
#!pip install python-dotenv
import os
from dotenv import load_dotenv
# load the .env environment variables into the notebook
load_dotenv()
#Get the API key from the environment variable as Python variable
weather_api_key = os.getenv("weather_api_key")

# %%
# Build query URL and request your results in Celsius
query_url = url + "appid=" + open_weather_api + "&q=" + city + "&units=" +units
query_url = f"{url}appid{query_url} = url + "appid=" + open_weather_api + "&q=" + city + "&units=" + units}&q={city}&units={units}"
print(query_url)
# Out:
#   File "<ipython-input-33-df02b20c675a>", line 3
#     query_url = f"{url}appid{query_url} = url + "appid=" + open_weather_api + "&q=" + city + "&units=" + units}&q={city}&units={units}"
#                                                      ^
# SyntaxError: invalid syntax

# %%
# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()
print(weather_json)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-3982f6763135> in <module>
#       1 # Get weather data
# ----> 2 weather_response = requests.get(query_url)
#       3 weather_json = weather_response.json()
#       4 print(weather_json)
#
# NameError: name 'query_url' is not defined

# %%
# Get temperature from JSON response
temperature = weather_json["main"]["temp"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-7107089f9cf9> in <module>
#       1 # Get temperature from JSON response
# ----> 2 temperature = weather_json["main"]["temp"]
#
# NameError: name 'weather_json' is not defined

# %%
# report temperature
print(f"The temperature in Bujumbura is{temperature} C.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-b1b1949795f6> in <module>
#       1 # report temperature
# ----> 2 print(f"The temperature in Bujumbura is{temperature} C.")
#
# NameError: name 'temperature' is not defined

# %%
#cities = ["Paris", "London", "Oslo", "Bejing"]

# %%
# Dependencies
import json
import requests
from config import weather_api_key
from pprint import pprint

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "Bujumbura"
units = "metric"

# %%
# Build query URL and request your results in Celsius
query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"

# %%
# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()
pprint(weather_json)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 95},
#  'cod': 200,
#  'coord': {'lat': -3.3822, 'lon': 29.3644},
#  'dt': 1634352051,
#  'id': 425378,
#  'main': {'feels_like': 23.43,
#           'grnd_level': 923,
#           'humidity': 79,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 23.01,
#           'temp_max': 23.01,
#           'temp_min': 23.01},
#  'name': 'Bujumbura',
#  'rain': {'1h': 0.21},
#  'sys': {'country': 'BI', 'sunrise': 1634355746, 'sunset': 1634399605},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 18, 'gust': 2.28, 'speed': 1.5}}

# %%
# Get the temperature from JSON response
temperature = weather_json["main"]["temp"]
temperature
# Out:
# 23.01

# %%
# Report temperature
print(f" The temperature in Bujumbura is {temperature} C.")
# Out:
#  The temperature in Bujumbura is 23.01 C.

# %%
# Bonus

# use list of units
units = ["metric", "imperial"]

# set up list to hold two different temperatures
temperatures = []

# loop through the list of units and append them  to temperatures list 
for unit in units:
    # Build query URL based on current element in units
    query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + unit
    
    # Get weather data
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    
    # Get temperature from JSON response
    temperature = weather_json["main"]["temp"]
    
    temperatures.append(temperature)

# Report temperature by accessing each element in the list
print(f"The temperature in Bujumbura is {temperatures[0]}C or {temperatures[1]}F.")
# Out:
# The temperature in Bujumbura is 23.01C or 73.42F.

# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import weather_api_key

# %%
# save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# build a parial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
cities = ["Houston", "Boston", "Paris", "London", "Oslo", "Beijing"]

# set up lists to hold response info
lat = []
temp = []
dic = []

# Loop through the cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    a = {
        "city": response['name'],
        "lat": response['coord']['lat'],
        "lon": response['coord']['lon'],
        "temp": response['main']['temp']   
    }
    dic.append(a)
    lat.append(response['coord']['lat'])
    temp.append(response['main']['temp'])
    
print(f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
# Out:
# The latitude information received is: [29.7633, 42.3584, 48.8534, 51.5085, 59.9127, 39.9075]
# The temperature information received is: [77.18, 64.92, 49.91, 47.03, 41.47, 48.09]

# %%
dic
# Out:
# [{'city': 'Houston', 'lat': 29.7633, 'lon': -95.3633, 'temp': 77.18},
#  {'city': 'Boston', 'lat': 42.3584, 'lon': -71.0598, 'temp': 64.92},
#  {'city': 'Paris', 'lat': 48.8534, 'lon': 2.3488, 'temp': 49.91},
#  {'city': 'London', 'lat': 51.5085, 'lon': -0.1257, 'temp': 47.03},
#  {'city': 'Oslo', 'lat': 59.9127, 'lon': 10.7461, 'temp': 41.47},
#  {'city': 'Beijing', 'lat': 39.9075, 'lon': 116.3972, 'temp': 48.09}]

# %%
weather_data = pd.DataFrame(dic)
weather_data.set_index('city')
# Out:
#              lat       lon   temp
# city
# Houston  29.7633  -95.3633  77.18
# Boston   42.3584  -71.0598  64.92
# Paris    48.8534    2.3488  49.91
# London   51.5085   -0.1257  47.03
# Oslo     59.9127   10.7461  41.47
# Beijing  39.9075  116.3972  48.09

# %%
# create a data frame for cities, lat, and temp
weather_dict = {
    "city": cities,
    "lat": lat,
    "temp": temp
}

weather_dict = pd.DataFrame(weather_dict)
weather_dict.head()
# Out:
#       city      lat   temp
# 0  Houston  29.7633  77.18
# 1   Boston  42.3584  64.92
# 2    Paris  48.8534  49.91
# 3   London  51.5085  47.03
# 4     Oslo  59.9127  41.47

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o")

# incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.xlabel("Temperature (Celsius)")
plt.ylabel("Latitude")
plt.grid(True)

# save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %%
# 2.6
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# store the url
base_url = "https://api.tvmaze.com/search/shows?q="

# %%
# store the name and rating of shows in the list
show_title = []
rating = []
networks = []

# Sample shows to query
tv_shows = ["Altered Carbon", "Grey's Anatomy", "This is Us", "The Flash",
            "Vikings", "Shameless", "Arrow", "Peaky Blinders", "Dirk Gently"]


# networks.append(response[0]["show"]["network"]["name"])

# loop through tv show titles, make requests and parse
for show in tv_shows:
    target_url = base_url + show
    response = requests.get(target_url).json()
    show_title.append(response[0]["show"]["name"])
    rating.append(response[0]["show"]["rating"]["average"])

# %%
# create dataframe
show_df = pd.DataFrame({
    "title": show_title,
    "rating": rating
    
})

show_df.append
# Out:
# <bound method DataFrame.append of             title  rating
# 0  Altered Carbon     8.1
# 1  Grey's Anatomy     7.9
# 2      This Is Us     7.9
# 3       The Flash     7.8
# 4         Vikings     8.7
# 5       Shameless     8.5
# 6           Arrow     7.4
# 7  Peaky Blinders     8.7
# 8     Dirk Gently     7.3>

# %%
tv_show_networks =("Netflix", "ABC", "NBC", "The CW", "History", "Showtime", "The CW", "BBC", "BBC")

# %%
show_df["Network"] = np.array(tv_show_networks)
show_df
# Out:
#             title  rating   Network
# 0  Altered Carbon     8.1   Netflix
# 1  Grey's Anatomy     7.9       ABC
# 2      This Is Us     7.9       NBC
# 3       The Flash     7.8    The CW
# 4         Vikings     8.7   History
# 5       Shameless     8.5  Showtime
# 6           Arrow     7.4    The CW
# 7  Peaky Blinders     8.7       BBC
# 8     Dirk Gently     7.3       BBC

# %%
show_df.plot(x='title', y='rating', kind='bar', figsize=(10,5), rot=45)
# Out:
# <AxesSubplot:xlabel='title'>

# %%
st = show_df["rating"].std()
show_df.plot(x='title', y='rating', kind='bar', rot=45, ylim=(show_df["rating"].min()-st, show_df["rating"].max()+st))
# Out:
# <AxesSubplot:xlabel='title'>

# %%
#2.7
# Dependencies
import csv
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
from config import weather_api_key

# %%
# save config info
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
    
# Create search query, make request and store in json
query_url = f"{url}appid={api_key}&units={units}&q="
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-e9d976c25f69> in <module>
#       4
#       5 # Create search query, make request and store in json
# ----> 6 query_url = f"{url}appid={api_key}&units={units}&q="
#
# NameError: name 'api_key' is not defined

# %%
cities = ["Paris", "London", "Oslo", "Beijing", "Mumbai", "New York", "Seattle", "Dallas", "Taipei"]

# set up  lists to hold the response info
temperature = []
latitude = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    latitude.append(response['coord']['lat'])
    temperature.append(response['main']['temp'])
    
print(f"The latitude information received is: {latitude}")
print(f"The temperature information received is: {temperature}")
# Out:
# The latitude information received is: [48.8534, 51.5085, 59.9127, 39.9075, 19.0144, 40.7143, 47.6062, 32.7668, 25.0478]
# The temperature information received is: [49.57, 47.1, 41.47, 50.81, 82.38, 69.55, 56.95, 63.66, 86.86]

# %%
# create a dataframe from cities, lat, and temp
weather_dict = {
    "city": cities,
    "lat": latitude,
    "temp": temperature
    }

weather_data = pd.DataFrame(weather_dict)
weather_data.set_index("city")
# Out:
#               lat   temp
# city
# Paris     48.8534  49.57
# London    51.5085  47.10
# Oslo      59.9127  41.47
# Beijing   39.9075  50.81
# Mumbai    19.0144  82.38
# New York  40.7143  69.55
# Seattle   47.6062  56.95
# Dallas    32.7668  63.66
# Taipei    25.0478  86.86

# %%
weather_data[["lat", "temp"]].plot()
# Out:
# <AxesSubplot:>

# %%
# create a scatter plot for temperature vs latitude
x_values = weather_data['lat']
y_values = weather_data['temp']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Temperature relative to Latitude')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# get regression values
regress_values = x_values * slope + intercept
print(regress_values)
# Out:
# 0    51.773105
# 1    48.830777
# 2    39.517413
# 3    61.686770
# 4    84.840080
# 5    60.792691
# 6    53.155227
# 7    69.599949
# 8    78.153989
# Name: lat, dtype: float64

# %%
# create a line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = -1.11x +105.91

# %%
# create a plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# label plot and annotate the line equation
plt.xlabel('latitude')
plt.ylabel('temperature')
plt.annotate(line_eq,(20,15), fontsize=15, color="red")

# print r square values
print(f"The r-squared is: {rvalue**2}")

# show plot
plt.show
# Out:
# The r-squared is: 0.8335278759937386
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Calculate the temperature for Florence at 43.77 degress
florence_lat = 43.77
florence_predict_temp = round(slope * florence_lat + intercept,2)

print(f"The predicited temperature for Florence will be {florence_predict_temp}.")
# Out:
# The predicited temperature for Florence will be 57.41.

# %%
# use the API to determine actual temperature
response = requests.get(query_url + "Florence").json()
florence_actual_temp = response['main']['temp']

print(f"The actual temperature for Florence is {florence_actual_temp}.")
# Out:
# The actual temperature for Florence is 46.89.

# %%
print(rvalue, pvalue, stderr)
# Out:
# -0.9129774783606321 0.0005873812989323505 0.18718536181691817

# %%
#2.8 TRY

students = {
    # Name  : Age
    "James": 27,
    "Sarah": 19,
    "Jocelyn": 28
}

print(students["Jezebel"])

print("This line will never print")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-46413c4f99a2> in <module>
#       8 }
#       9
# ---> 10 print(students["Jezebel"])
#      11
#      12 print("This line will never print")
#
# KeyError: 'Jezebel'

# %%
import sys
try:
    print(students["James"])
    a = 4
    b = 0 
    d = a / b
except KeyError:
    print("we have KeyError") 
except ZeroDivisionError:
    print("we have ZeroDivisionError")
    print(f"we have unexpected error: sys.exc_info()")
finally:
    print("anyway")
# Out:
# 27
# we have ZeroDivisionError
# we have unexpected error: sys.exc_info()
# anyway

# %%
students = {
    # Name  : Age
    "James": 27,
    "Sarah": 19,
    "Jocelyn": 28
}

# Try to access key that doesn't exist
try:
    students["Jezebel"]
except KeyError:
    print("Oops, that key doesn't exist.")
except TypeError:
    print("Oops, you wrote a typo AGAIN :).")
except (RuntimeError, NameError):
    print("oops, that key doesn't exist.")
except:
    print(f"Unexpected error: {sys.exc_into()}")
finally:
    print("This line will be printed anyway!")
    print('-----------------')
# Catching the errors lets the rest of our code execute
    print("... But the program doesn't die early!")
# Out:
# Oops, that key doesn't exist.
# This line will be printed anyway!
# -----------------
# ... But the program doesn't die early!

# %%
#2.9

# %%
try:
    print("Infinity looks like + " + str(10 / 0) + ".")
except ZeroDivisionError: 
    print("I think you break math")
try:
    print("I think her name was + " + name + "?")
except NameError:
    print("You forgot her name")
try:
    print("Your name is a nonsense number. Look: " + int("Gabriel"))
except ValueError:
    print("You don't have a barcode")

print("You made it through the gauntlet--the message survived!")
# Out:
# I think you break math
# You forgot her name
# You don't have a barcode
# You made it through the gauntlet--the message survived!

# %%
#2.9 
# Dependencies
import json
import requests
import pandas as pd

# %%
# list of character
search_character = ['R2-D2', 'Darth Vader', 'Godzilla', 'Luke Skywalker', 'Frodo', \
              'Boba Fett', 'Iron Man', 'Jon Snow', 'Han Solo']

# set url for API
url = 'https://swapi.dev/api/people/?search='

# set empty lists to hold character's height and mass
height = []
mass = []
sw_character = []

# Loop through each character and make API request
for character in search_character:
    
    # create search query, make request and store in json
    response_json = requests.get(url + character).json()
    
    # try to grab  the height and mass if they are in the api
    try:
        height.append(response_json['results'][0]['height'])
        mass.append(response_json['results'][0]['mass'])
        sw_character.append(character)
        print(f"{character} found! Appending results")
        
    # Handle exceptions for a character that is not available in the Star Wars API
    except:
        # Append null values
        err = sys.exc_info()
        print(f"Unexpected error: {str(err[0])} {str(err[1])}")
        print(f"Character {character} not found")
        pass
# Out:
# R2-D2 found! Appending results
# Darth Vader found! Appending results
# Unexpected error: <class 'IndexError'> list index out of range
# Character Godzilla not found
# Luke Skywalker found! Appending results
# Unexpected error: <class 'IndexError'> list index out of range
# Character Frodo not found
# Boba Fett found! Appending results
# Unexpected error: <class 'IndexError'> list index out of range
# Character Iron Man not found
# Unexpected error: <class 'IndexError'> list index out of range
# Character Jon Snow not found
# Han Solo found! Appending results

# %%
# Create DataFrame
character_height = pd.DataFrame({
    'character': sw_character,
    'height': height,
    'mass': mass
})
character_height
# Out:
#         character height  mass
# 0           R2-D2     96    32
# 1     Darth Vader    202   136
# 2  Luke Skywalker    172    77
# 3       Boba Fett    183  78.2
# 4        Han Solo    180    80

# %%
# This owuld have been cool
#  except:
#        # Append null values
#        err = sys.exc_info()
#    try:
#        print(f'Help me {name}, youre my only hope!")
#    except NameError:
#        print("Stop where you are")
#    try:
#        print(f" {height} aren't you a little short to be a stormtrooper?)      
#    except ValueError:
#        print(f"These aren't the droids we're looking for)
#    print("They may go about their business + " + name + "?")3

#    except:

# %%
#2.10
# Dependencies
import requests

url = "http://api.worldbank.org/v2/"
api_format = "json"

# get the country info from JSON format
countries_response = requests.get(f"{url}countries?format={api_format}").json()

# first element is general info, and second is country's names
countries = countries_response[1]

# %%
#Report the names
all = []
for country in countries:
    url = f"http://api.worldbank.org/v2/country/{country['iso2Code']}?format=json"
    print(country["name"])
    req = requests.get(url).json()[1][0]
#    print(req)
    dict_a = {
        "id": country['id'],
        "iso2Code": country['iso2Code'],
        "name": country['name'],
        "incomeLevel": req['incomeLevel']['value']     
        }
    all.append(dict_a)
    print(url)
# Out:
# Aruba
# http://api.worldbank.org/v2/country/AW?format=json
# Africa Eastern and Southern
# http://api.worldbank.org/v2/country/ZH?format=json
# Afghanistan
# http://api.worldbank.org/v2/country/AF?format=json
# Africa
# http://api.worldbank.org/v2/country/A9?format=json
# Africa Western and Central
# http://api.worldbank.org/v2/country/ZI?format=json
# Angola
# http://api.worldbank.org/v2/country/AO?format=json
# Albania
# http://api.worldbank.org/v2/country/AL?format=json
# Andorra
# http://api.worldbank.org/v2/country/AD?format=json
# Arab World
# http://api.worldbank.org/v2/country/1A?format=json
# United Arab Emirates
# http://api.worldbank.org/v2/country/AE?format=json
# Argentina
# http://api.worldbank.org/v2/country/AR?format=json
# Armenia
# http://api.worldbank.org/v2/country/AM?format=json
# American Samoa
# http://api.worldbank.org/v2/country/AS?format=json
# Antigua and Barbuda
# http://api.worldbank.org/v2/country/AG?format=json
# Australia
# http://api.worldbank.org/v2/country/AU?format=json
# Austria
# http://api.worldbank.org/v2/country/AT?format=json
# Azerbaijan
# http://api.worldbank.org/v2/country/AZ?format=json
# Burundi
# http://api.worldbank.org/v2/country/BI?format=json
# East Asia & Pacific (IBRD-only countries)
# http://api.worldbank.org/v2/country/B4?format=json
# Europe & Central Asia (IBRD-only countries)
# http://api.worldbank.org/v2/country/B7?format=json
# Belgium
# http://api.worldbank.org/v2/country/BE?format=json
# Benin
# http://api.worldbank.org/v2/country/BJ?format=json
# Burkina Faso
# http://api.worldbank.org/v2/country/BF?format=json
# Bangladesh
# http://api.worldbank.org/v2/country/BD?format=json
# Bulgaria
# http://api.worldbank.org/v2/country/BG?format=json
# IBRD countries classified as high income
# http://api.worldbank.org/v2/country/B1?format=json
# Bahrain
# http://api.worldbank.org/v2/country/BH?format=json
# Bahamas, The
# http://api.worldbank.org/v2/country/BS?format=json
# Bosnia and Herzegovina
# http://api.worldbank.org/v2/country/BA?format=json
# Latin America & the Caribbean (IBRD-only countries)
# http://api.worldbank.org/v2/country/B2?format=json
# Belarus
# http://api.worldbank.org/v2/country/BY?format=json
# Belize
# http://api.worldbank.org/v2/country/BZ?format=json
# Middle East & North Africa (IBRD-only countries)
# http://api.worldbank.org/v2/country/B3?format=json
# Bermuda
# http://api.worldbank.org/v2/country/BM?format=json
# Bolivia
# http://api.worldbank.org/v2/country/BO?format=json
# Brazil
# http://api.worldbank.org/v2/country/BR?format=json
# Barbados
# http://api.worldbank.org/v2/country/BB?format=json
# Brunei Darussalam
# http://api.worldbank.org/v2/country/BN?format=json
# Sub-Saharan Africa (IBRD-only countries)
# http://api.worldbank.org/v2/country/B6?format=json
# Bhutan
# http://api.worldbank.org/v2/country/BT?format=json
# Botswana
# http://api.worldbank.org/v2/country/BW?format=json
# Sub-Saharan Africa (IFC classification)
# http://api.worldbank.org/v2/country/C9?format=json
# Central African Republic
# http://api.worldbank.org/v2/country/CF?format=json
# Canada
# http://api.worldbank.org/v2/country/CA?format=json
# East Asia and the Pacific (IFC classification)
# http://api.worldbank.org/v2/country/C4?format=json
# Central Europe and the Baltics
# http://api.worldbank.org/v2/country/B8?format=json
# Europe and Central Asia (IFC classification)
# http://api.worldbank.org/v2/country/C5?format=json
# Switzerland
# http://api.worldbank.org/v2/country/CH?format=json
# Channel Islands
# http://api.worldbank.org/v2/country/JG?format=json
# Chile
# http://api.worldbank.org/v2/country/CL?format=json

# %%
# First element is general information, second is countries themselves

# %%
# Report the names
df = pd.DataFrame(all)
df.head()
# Out:
#     id iso2Code                         name  incomeLevel
# 0  ABW       AW                        Aruba  High income
# 1  AFE       ZH  Africa Eastern and Southern   Aggregates
# 2  AFG       AF                  Afghanistan   Low income
# 3  AFR       A9                       Africa   Aggregates
# 4  AFW       ZI   Africa Western and Central   Aggregates

# %%
df["incomeLevel"].value_counts()
# Out:
# High income            16
# Aggregates             14
# Upper middle income    10
# Lower middle income     6
# Low income              4
# Name: incomeLevel, dtype: int64

# %%
#2.12

# %%
# Dependencies
import requests
url = "http://api.worldbank.org/v2/"

# %%
# Get the list of lending types the world bank has
lending_response = requests.get(f"{url}lendingTypes?format=json").json()[1]

# %%
print(json.dumps(lending_response, indent=4))
# Out:
# [
#     {
#         "id": "IBD",
#         "iso2code": "XF",
#         "value": "IBRD"
#     },
#     {
#         "id": "IDB",
#         "iso2code": "XH",
#         "value": "Blend"
#     },
#     {
#         "id": "IDX",
#         "iso2code": "XI",
#         "value": "IDA"
#     },
#     {
#         "id": "LNX",
#         "iso2code": "XX",
#         "value": "Not classified"
#     }
# ]

# %%
lending_types = [x["id"] for x in lending_response]
lending_types
# Out:
# ['IBD', 'IDB', 'IDX', 'LNX']

# %%
lending_types = {}
for lend in lending_types:
    lendingtype[lend] = []
    url2 = f"http://api.worldbank.org/v2/country?lendingtype={lend}&format=json"
    response = requests.get(url2).json()[1]
    for country in response:
        lendingtype[lend].append(country["name"])

# %%
# print(response[0]["name"])
for lend in lending_types:
    print(lend, len(lendingtype[lend]))

# %%
lending_types = [lending_type["id"] for lending_type in lending_response]
lending_types
# Out:
# ['IBD', 'IDB', 'IDX', 'LNX']

# %%
# Next determine how many countries fall into each lending type
# Hint: Look at the first element of the response array.
country_count_by_type = {}
for lending_type in lending_types:
    query = f"{url}countries?lendingType={lending_type}&format=json"
    response = requests.get(query).json()
    country_count_by_type[lending_type] = response[0]["total"]
country_count_by_type
# Out:
# {'IBD': 140, 'IDB': 30, 'IDX': 118, 'LNX': 74}

# %%
for k, v in country_count_by_type.items():
    print(k, v)
# Out:
# IBD 140
# IDB 30
# IDX 118
# LNX 74

# %%
# Print the number of countries of each lending type
for key, value in country_count_by_type.items():
    print(f"The number of countries with lending type {key} is {value}.")
# Out:
# The number of countries with lending type IBD is 140.
# The number of countries with lending type IDB is 30.
# The number of countries with lending type IDX is 118.
# The number of countries with lending type LNX is 74.

# %%
# Your assignment is to get the last line to print without changing any
# of the code below. Instead, wrap each line that throws an error in a
# try/exept block.

try:
    print("Infinity looks like + " + str(10 / 0) + ".")
except ZeroDivisionError:
    print("Woops. Can't do that.")

try:
    print("I think her name was + " + name + "?")
except NameError:
    print("Oh, I forgot to define 'name'. D'oh.")

try:
    print("Your name is a nonsense number. Look: " + int("Gabriel"))
except ValueError:
    print("Drat. 'Gabriel' isn't a number?")

print("I made it through the gauntlet. The message survived!")
# Out:
# Woops. Can't do that.
# Oh, I forgot to define 'name'. D'oh.
# Drat. 'Gabriel' isn't a number?
# I made it through the gauntlet. The message survived!
